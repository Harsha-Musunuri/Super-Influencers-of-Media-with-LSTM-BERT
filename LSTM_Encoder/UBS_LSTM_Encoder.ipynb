# %% [markdown]
# # In this notebook, we will create a LSTM Encoder from scratch!

# %% [markdown]
# ## Import Packages

# %%
#Data Handling Libraries
import collections
import pandas as pd
import numpy as np
import random

#Tensorflow
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GRU, Input, Dense, TimeDistributed,LSTM, Activation, RepeatVector, Bidirectional,Embedding,LayerNormalization, Lambda, dot, Activation, concatenate 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras import layers 
from tensorflow.keras.layers import Layer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
import tensorflow.keras.backend as K

# %% [markdown]
# ## Import Google Drive!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Articles i:e Dataset

# %%
data=pd.read_csv("/content/drive/My Drive/Colab Notebooks/UBS_Pitch/News_Category.csv")

# %%
data = data[data['headline'].notnull()] #Removing NULL rows if any!

# %%
headlines = data['headline'].to_list() #selecting the target column - Headlines!

# %%
headlines[0]
# Out:
# 'There Were 2 Mass Shootings In Texas Last Week, But Only 1 On TV'

# %%
len(headlines)
# Out:
# 200847

# %%
random.shuffle(headlines) #breaking order

# %%
headlines[0]
# Out:
# 'Top 13 Wedding Trends for 2013'

# %%
headlines_counter = collections.Counter([word for sentence in headlines for word in sentence.split()])

print('{} Words.'.format(len([word for sentence in headlines for word in sentence.split()])))
print('{} unique words.'.format(len(headlines_counter)))
print('10 Most common words in the titles:')
print('"' + '" "'.join(list(zip(*headlines_counter.most_common(20)))[0]) + '"')
# Out:
# 1915849 Words.
# 119488 unique words.
# 10 Most common words in the titles:
# "The" "To" "A" "In" "Of" "For" "Is" "And" "On" "With" "the" "to" "You" "Your" "How" "of" "Trump" "(PHOTOS)" "New" "and"

# %% [markdown]
# ## Functions for preprocessing!

# %% [markdown]
# #### Tokenization via Tokenizer function from TF

# %%
def tokenize(x):
    """
    Tokenize x
    :param x: List of sentences/strings to be tokenized
    :return: Tuple of (tokenized x data, tokenizer used to tokenize x)
    """
    x_tk = Tokenizer()
    x_tk.fit_on_texts(x)
    return x_tk.texts_to_sequences(x), x_tk

# %% [markdown]
# #### padding all the article's token list, so that all of them be the same length via pad_sequences function from TF

# %%
def pad(x, length=None):
    """
    Pad x
    :param x: List of sequences.
    :param length: Length to pad the sequence to.  If None, use length of longest sequence in x.
    :return: Padded numpy array of sequences
    """
    if length is None:
        # Find the length of the longest sequence/sentence
        length = max([len(seq) for seq in x])
    
    return pad_sequences(sequences=x, maxlen=length, padding='post')

# %% [markdown]
# #### preprocess function that uses above two functions to preprocess all articles, it also gives us
# 1. max headline length (which is used in the NN pipeline)
# 2. Total vocab size (which is used in the NN pipeline)

# %%
def preprocess(x):
    """
    Preprocess x and y
    :param x: Feature List of sentences
    :param y: Label List of sentences
    :return: Tuple of (Preprocessed x, Preprocessed y, x tokenizer, y tokenizer)
    """
    preprocess_x, x_tk = tokenize(x)
    preprocess_x = pad(preprocess_x)

    return preprocess_x, x_tk

preproc_headlines, headlines_tokenizer = preprocess(headlines)
    
max_headline_sequence_length = preproc_headlines.shape[1]

headlines_vocab_size = len(headlines_tokenizer.word_index)


print('Data Preprocessed')
print("Max Headline length:", max_headline_sequence_length)
print("Headline vocabulary size:", headlines_vocab_size)
# Out:
# Data Preprocessed
# Max Headline length: 53
# Headline vocabulary size: 75639

# %% [markdown]
# ## Hyperparams for the NN pipeline

# %%
num_words = 75640
maxlen = 53
embed_dim = 128
batch_size = 16

# %% [markdown]
# ## LSTM Encoder_Decoder Architecture

# %% [markdown]
# #### Attention Module

# %%
class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")        
        super(attention, self).build(input_shape)

    def call(self,x):
        et=K.squeeze(K.tanh(K.dot(x,self.W)+self.b),axis=-1)
        at=K.softmax(et)
        at=K.expand_dims(at,axis=-1)
        output=x*at
        return K.sum(output,axis=1)

    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()

# %% [markdown]
# #### Encoder

# %% [markdown]
# ###### max headline length (maxlen, should be the input size)
# ##### Total vocab size - num_words
# ##### Note: num_words = Total vocab size + 1

# %%
encoder_inputs = Input(shape=(maxlen,), name='Encoder-Input')
emb_layer = Embedding(num_words, embed_dim,input_length = maxlen, name='Body-Word-Embedding', mask_zero=False)
x = emb_layer(encoder_inputs)

state_h = Bidirectional(LSTM(128, activation='relu', name='Encoder-Last-LSTM', return_sequences=True))(x)
norm = LayerNormalization(axis=1)(state_h)
state_h = Bidirectional(LSTM(128, activation='relu', name='Encoder-Last-LSTM',return_sequences=True))(norm)
norm = LayerNormalization(axis=1)(state_h)
state_h = Bidirectional(LSTM(128, activation='relu', name='Encoder-Last-LSTM',return_sequences=False))(norm)
norm = LayerNormalization(axis=1)(state_h)


att_out=attention()(norm)
encoder_model = Model(inputs=encoder_inputs, outputs=norm, name='Encoder-Model')
seq2seq_encoder_out = encoder_model(encoder_inputs)

# %% [markdown]
# #### Decoder

# %%
decoded = RepeatVector(maxlen)(seq2seq_encoder_out)
decoder_lstm = Bidirectional(LSTM(128, return_sequences=True, name='Decoder-LSTM-before'),merge_mode='sum')
decoder_lstm_output = decoder_lstm(decoded)
norm = layers.LayerNormalization(axis=1)(decoder_lstm_output)
decoder_dense = Dense(num_words, activation='softmax', name='Final-Output-Dense-before')
decoder_outputs = decoder_dense(norm)

# %% [markdown]
# ## Define NN using above blocks and Start the training!
#
# ### Training takes huge time! You can use the trained models saved in saveModel folder!

# %%
tf.debugging.set_log_device_placement(True)
seq2seq_Model = Model(encoder_inputs, decoder_outputs)
print(seq2seq_Model.summary())
seq2seq_Model.compile(optimizer=tf.keras.optimizers.Nadam(lr=0.001), loss='sparse_categorical_crossentropy')
history = seq2seq_Model.fit(preproc_titles, np.expand_dims(preproc_titles, -1),
          batch_size=batch_size,
          epochs=10)

# %% [markdown]
# ## Save the trained model

# %%
seq2seq_Model.save('/content/drive/My Drive/Colab Notebooks/UBS_Pitch/saveModel/LSTM_EncoderDecoderTrained') 
encoder_model.save('/content/drive/My Drive/Colab Notebooks/UBS_Pitch/saveModel/LSTM_EncoderTrained')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/UBS_Pitch/saveModel/LSTM_EncoderDecoderTrained/assets
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/UBS_Pitch/saveModel/LSTM_EncoderTrained/assets

# %% [markdown]
# ## Load the saved Encoder model

# %%
encoder = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/UBS_Pitch/saveModel/LSTM_EncoderTrained')
encoder.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Model: "Encoder-Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Encoder-Input (InputLayer)   [(None, 33)]              0
# _________________________________________________________________
# Body-Word-Embedding (Embeddi (None, 33, 128)           3553664
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, 33, 256)           263168
# _________________________________________________________________
# layer_normalization_12 (Laye (None, 33, 256)           66
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, 33, 256)           394240
# _________________________________________________________________
# layer_normalization_13 (Laye (None, 33, 256)           66
# _________________________________________________________________
# bidirectional_14 (Bidirectio (None, 256)               394240
# _________________________________________________________________
# layer_normalization_14 (Laye (None, 256)               512
# =================================================================
# Total params: 4,605,956
# Trainable params: 4,605,956
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Using models for inference

# %%
Headlines_Inference=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/UBS_Pitch/41category500ArticlesEach.csv')

# %%
Headlines_Inference = Headlines_Inference['headline'].to_list()

# %%
len(Headlines_Inference)
# Out:
# 20500

# %%
from tqdm import tqdm

# %%
ArticleLatents=[]
# for i in tqdm(range(1)):
for sentence in tqdm(TitlesComparision):
    seq,seq_tokenizer = tokenize(sentence)
    pad_seq=pad_sequences(seq, maxlen=33, padding='post')
    sentence_vec = encoder.predict(pad_seq)[0]
    ArticleLatents.append(sentence_vec)
# Out:
# 100%|██████████| 20500/20500 [1:19:47<00:00,  4.28it/s]

# %%
articleLatentDF = pd.DataFrame(ArticleLatents)
articleLatentDF.to_csv('/content/drive/My Drive/Colab Notebooks/UBS_Pitch/articleToLatent.csv')
# Out:
# None

# %% [markdown]
# ## Cluster Purity
# ### Now that we have latents for each headline, we can use K-means to cluster these headlines. We are using a range of K values, to pick one best K value that could cluster the articles at the best. Ideal K value would be the number of Categories and it turns out with such K value, clusters are atleast 85% pure.
#
# ### Purity is measured as, lets say we are talking about cluster 1 - of the data avaible in that cluster if 85% of the articles are of a certain category then we can very well name that cluster with that category name and say it is 85% pure.

# %%
from sklearn.cluster import KMeans
from collections import Counter

file = ("/content/drive/My Drive/Colab Notebooks/UBS_Pitch/41category500ArticlesEach.csv")
dataset = pd.read_csv(file, delimiter=',')
# dataset = dataset.head(50000)
n_unique_cat = dataset['category'].nunique()
category = dataset['category'].values
ctr = Counter(category)
print(ctr)
print(n_unique_cat)
# ad
print(category.shape)
embeddings = pd.read_csv("/content/drive/My Drive/Colab Notebooks/UBS_Pitch/articleToLatent.csv")
print(embeddings.shape)
print("Embedding loading done")

for n_cluster in range(n_unique_cat,4*n_unique_cat):
  print("Num clust ", n_cluster)
  kmeans = KMeans(n_clusters=n_cluster).fit(embeddings)
  cluster_list = []
  for i in range(n_cluster):
    cluster_list.append([])
  
  labels = kmeans.labels_
  ctr = Counter(labels)
  print(ctr)
  for i in range(category.shape[0]-1):
    cluster_list[labels[i]].append(category[i])
  for i in range(len(cluster_list)):
    ctr = Counter(cluster_list[i])
    print(ctr.most_common(2))
    cls = ctr.most_common(1)[0][0]
    ct = ctr.most_common(1)[0][1]
    print(cls,ct*100/float(len(cluster_list[i])))
    print()
  # sd
# Out:
# Streaming output truncated to the last 5000 lines.
# MEDIA 100.0
#
# [('DIVORCE', 233), ('WEDDINGS', 96)]
# DIVORCE 70.82066869300913
#
# [('FOOD & DRINK', 231), ('MONEY', 111)]
# FOOD & DRINK 67.54385964912281
#
# [('ARTS', 261), ('WELLNESS', 48)]
# ARTS 84.46601941747574
#
# [('COMEDY', 337)]
# COMEDY 100.0
#
# [('HEALTHY LIVING', 296), ('THE WORLDPOST', 29)]
# HEALTHY LIVING 91.07692307692308
#
# [('GREEN', 286), ('TASTE', 46)]
# GREEN 86.144578313253
#
# [('WORLDPOST', 304), ('GOOD NEWS', 11)]
# WORLDPOST 96.5079365079365
#
# [('BLACK VOICES', 330), ('WEIRD NEWS', 10)]
# BLACK VOICES 97.05882352941177
#
# [('SPORTS', 332)]
# SPORTS 100.0
#
# [('STYLE', 336)]
# STYLE 100.0
#
# [('MONEY', 344)]
# MONEY 100.0
#
# [('IMPACT', 334)]
# IMPACT 100.0
#
# [('ARTS & CULTURE', 203), ('PARENTS', 138)]
# ARTS & CULTURE 59.530791788856305
#
# [('HOME & LIVING', 302), ('PARENTING', 15)]
# HOME & LIVING 95.26813880126183
#
# [('POLITICS', 184), ('WEIRD NEWS', 152)]
# POLITICS 54.76190476190476
#
# [('QUEER VOICES', 319), ('SPORTS', 14)]
# QUEER VOICES 95.7957957957958
#
# [('WOMEN', 330), ('COMEDY', 9)]
# WOMEN 97.34513274336283
#
# [('RELIGION', 334)]
# RELIGION 100.0
#
# [('WEDDINGS', 334)]
# WEDDINGS 100.0
#
# [('WORLD NEWS', 314), ('ENTERTAINMENT', 17)]
# WORLD NEWS 94.86404833836858
#
# [('ENVIRONMENT', 198), ('CULTURE & ARTS', 151)]
# ENVIRONMENT 56.73352435530086
#
# [('TRAVEL', 167), ('MEDIA', 161)]
# TRAVEL 50.91463414634146
#
# [('FIFTY', 312)]
# FIFTY 100.0
#
# [('SCIENCE', 176), ('LATINO VOICES', 160)]
# SCIENCE 52.38095238095238
#
# [('BUSINESS', 324), ('TRAVEL', 5)]
# BUSINESS 98.48024316109422
#
# [('PARENTING', 314)]
# PARENTING 100.0
#
# [('TASTE', 330)]
# TASTE 100.0
#
# [('THE WORLDPOST', 323)]
# THE WORLDPOST 100.0
#
# [('CRIME', 173), ('ENTERTAINMENT', 154)]
# CRIME 52.90519877675841
#
# [('TECH', 322), ('MEDIA', 9)]
# TECH 97.2809667673716
#
# [('WELLNESS', 311)]
# WELLNESS 100.0
#
# [('EDUCATION', 337), ('LATINO VOICES', 2)]
# EDUCATION 99.41002949852508
#
# [('STYLE & BEAUTY', 322)]
# STYLE & BEAUTY 100.0
#
# [('GOOD NEWS', 318)]
# GOOD NEWS 100.0
#
# Num clust  63
# Counter({36: 342, 9: 341, 19: 341, 28: 339, 31: 338, 49: 338, 22: 337, 45: 337, 5: 335, 4: 335, 15: 334, 40: 333, 37: 333, 32: 333, 52: 332, 54: 332, 25: 331, 0: 331, 3: 331, 16: 331, 26: 330, 47: 330, 46: 329, 57: 329, 38: 329, 13: 329, 43: 329, 50: 329, 14: 328, 60: 328, 21: 327, 8: 327, 2: 326, 29: 326, 48: 325, 33: 325, 6: 324, 41: 324, 44: 323, 18: 323, 39: 322, 7: 322, 58: 321, 20: 320, 24: 320, 42: 319, 34: 318, 53: 318, 23: 318, 10: 317, 61: 317, 11: 316, 59: 316, 56: 316, 30: 315, 17: 313, 55: 312, 51: 311, 12: 311, 27: 310, 1: 309, 62: 308, 35: 307})
# [('BLACK VOICES', 178), ('WOMEN', 153)]
# BLACK VOICES 53.77643504531722
#
# [('WORLDPOST', 309)]
# WORLDPOST 100.0
#
# [('RELIGION', 170), ('SCIENCE', 156)]
# RELIGION 52.147239263803684
#
# [('WEDDINGS', 308), ('FOOD & DRINK', 23)]
# WEDDINGS 93.05135951661632
#
# [('STYLE', 193), ('ARTS & CULTURE', 142)]
# STYLE 57.61194029850746
#
# [('ENTERTAINMENT', 325), ('WORLD NEWS', 10)]
# ENTERTAINMENT 97.01492537313433
#
# [('QUEER VOICES', 324)]
# QUEER VOICES 100.0
#
# [('HOME & LIVING', 322)]
# HOME & LIVING 100.0
#
# [('CULTURE & ARTS', 175), ('ENVIRONMENT', 152)]
# CULTURE & ARTS 53.51681957186544
#
# [('COLLEGE', 337), ('EDUCATION', 4)]
# COLLEGE 98.82697947214076
#
# [('HEALTHY LIVING', 315), ('TASTE', 2)]
# HEALTHY LIVING 99.36908517350157
#
# [('TRAVEL', 264), ('MEDIA', 52)]
# TRAVEL 83.54430379746836
#
# [('ARTS', 300), ('FIFTY', 11)]
# ARTS 96.46302250803859
#
# [('DIVORCE', 329)]
# DIVORCE 100.0
#
# [('POLITICS', 328)]
# POLITICS 100.0
#
# [('LATINO VOICES', 320), ('SCIENCE', 14)]
# LATINO VOICES 95.80838323353294
#
# [('MONEY', 312), ('ENVIRONMENT', 19)]
# MONEY 94.25981873111782
#
# [('THE WORLDPOST', 313)]
# THE WORLDPOST 100.0
#
# [('TASTE', 177), ('GREEN', 146)]
# TASTE 54.79876160990712
#
# [('PARENTS', 321), ('ARTS & CULTURE', 20)]
# PARENTS 94.13489736070382
#
# [('SPORTS', 220), ('BUSINESS', 100)]
# SPORTS 68.75
#
# [('COMEDY', 309), ('WOMEN', 18)]
# COMEDY 94.4954128440367
#
# [('ENTERTAINMENT', 175), ('CRIME', 162)]
# ENTERTAINMENT 51.92878338278932
#
# [('PARENTING', 256), ('HOME & LIVING', 62)]
# PARENTING 80.50314465408805
#
# [('TECH', 313), ('RELIGION', 7)]
# TECH 97.8125
#
# [('IMPACT', 174), ('WORLD NEWS', 157)]
# IMPACT 52.56797583081571
#
# [('WEIRD NEWS', 330)]
# WEIRD NEWS 100.0
#
# [('GOOD NEWS', 245), ('WORLDPOST', 65)]
# GOOD NEWS 79.03225806451613
#
# [('EDUCATION', 339)]
# EDUCATION 100.0
#
# [('STYLE & BEAUTY', 292), ('DIVORCE', 34)]
# STYLE & BEAUTY 89.57055214723927
#
# [('WELLNESS', 315)]
# WELLNESS 100.0
#
# [('CRIME', 338)]
# CRIME 100.0
#
# [('FOOD & DRINK', 333)]
# FOOD & DRINK 100.0
#
# [('CULTURE & ARTS', 324)]
# CULTURE & ARTS 100.0
#
# [('BUSINESS', 318)]
# BUSINESS 100.0
#
# [('FIFTY', 181), ('WORLDPOST', 126)]
# FIFTY 58.957654723127035
#
# [('PARENTS', 179), ('COLLEGE', 163)]
# PARENTS 52.33918128654971
#
# [('STYLE', 307), ('GREEN', 26)]
# STYLE 92.1921921921922
#
# [('WOMEN', 329)]
# WOMEN 100.0
#
# [('SPORTS', 280), ('QUEER VOICES', 42)]
# SPORTS 86.95652173913044
#
# [('WORLD NEWS', 333)]
# WORLD NEWS 100.0
#
# [('STYLE & BEAUTY', 208), ('HOME & LIVING', 116)]
# STYLE & BEAUTY 64.19753086419753
#
# [('TECH', 187), ('MEDIA', 132)]
# TECH 58.62068965517241
#
# [('WEDDINGS', 192), ('DIVORCE', 137)]
# WEDDINGS 58.358662613981764
#
# [('RELIGION', 323)]
# RELIGION 100.0
#
# [('LATINO VOICES', 180), ('EDUCATION', 157)]
# LATINO VOICES 53.41246290801187
#
# [('IMPACT', 326), ('POLITICS', 3)]
# IMPACT 99.08814589665654
#
# [('SCIENCE', 330)]
# SCIENCE 100.0
#
# [('COMEDY', 191), ('QUEER VOICES', 134)]
# COMEDY 58.76923076923077
#
# [('ARTS & CULTURE', 338)]
# ARTS & CULTURE 100.0
#
# [('ENVIRONMENT', 329)]
# ENVIRONMENT 100.0
#
# [('GOOD NEWS', 255), ('THE WORLDPOST', 56)]
# GOOD NEWS 81.9935691318328
#
# [('BLACK VOICES', 322), ('WEIRD NEWS', 10)]
# BLACK VOICES 96.98795180722891
#
# [('TRAVEL', 236), ('BUSINESS', 82)]
# TRAVEL 74.21383647798743
#
# [('MONEY', 188), ('FOOD & DRINK', 144)]
# MONEY 56.626506024096386
#
# [('ARTS', 200), ('WELLNESS', 112)]
# ARTS 64.1025641025641
#
# [('HEALTHY LIVING', 185), ('THE WORLDPOST', 131)]
# HEALTHY LIVING 58.54430379746835
#
# [('POLITICS', 169), ('WEIRD NEWS', 160)]
# POLITICS 51.367781155015194
#
# [('TASTE', 321)]
# TASTE 100.0
#
# [('MEDIA', 316)]
# MEDIA 100.0
#
# [('GREEN', 328)]
# GREEN 100.0
#
# [('PARENTING', 244), ('WELLNESS', 73)]
# PARENTING 76.97160883280758
#
# [('FIFTY', 308)]
# FIFTY 100.0
#
# Num clust  64
# Counter({34: 336, 62: 336, 36: 335, 0: 334, 15: 334, 33: 334, 5: 334, 18: 333, 43: 333, 17: 333, 7: 332, 41: 332, 30: 332, 53: 332, 38: 331, 27: 330, 28: 330, 13: 329, 24: 328, 12: 328, 56: 328, 57: 328, 1: 328, 54: 326, 47: 326, 37: 325, 32: 325, 16: 325, 25: 324, 4: 323, 11: 323, 44: 323, 8: 322, 61: 321, 31: 321, 26: 320, 35: 320, 51: 320, 9: 320, 42: 319, 39: 319, 19: 317, 22: 316, 14: 316, 49: 315, 40: 314, 50: 314, 6: 313, 23: 311, 63: 311, 55: 310, 3: 309, 52: 308, 2: 306, 46: 305, 21: 304, 60: 303, 20: 302, 45: 301, 10: 300, 29: 299, 59: 299, 58: 298, 48: 297})
# [('WOMEN', 334)]
# WOMEN 100.0
#
# [('STYLE & BEAUTY', 310), ('HOME & LIVING', 18)]
# STYLE & BEAUTY 94.51219512195122
#
# [('GREEN', 282), ('STYLE', 24)]
# GREEN 92.15686274509804
#
# [('SCIENCE', 309)]
# SCIENCE 100.0
#
# [('WORLD NEWS', 284), ('ENTERTAINMENT', 39)]
# WORLD NEWS 87.92569659442725
#
# [('ARTS', 182), ('WELLNESS', 152)]
# ARTS 54.49101796407186
#
# [('CULTURE & ARTS', 189), ('ENVIRONMENT', 124)]
# CULTURE & ARTS 60.38338658146965
#
# [('SPORTS', 238), ('BUSINESS', 94)]
# SPORTS 71.6867469879518
#
# [('GOOD NEWS', 173), ('THE WORLDPOST', 149)]
# GOOD NEWS 53.72670807453416
#
# [('FOOD & DRINK', 320)]
# FOOD & DRINK 100.0
#
# [('COLLEGE', 178), ('EDUCATION', 122)]
# COLLEGE 59.333333333333336
#
# [('MEDIA', 323)]
# MEDIA 100.0
#
# [('POLITICS', 237), ('WEIRD NEWS', 91)]
# POLITICS 72.2560975609756
#
# [('WORLDPOST', 175), ('FIFTY', 154)]
# WORLDPOST 53.191489361702125
#
# [('HEALTHY LIVING', 285), ('THE WORLDPOST', 31)]
# HEALTHY LIVING 90.18987341772151
#
# [('QUEER VOICES', 334)]
# QUEER VOICES 100.0
#
# [('DIVORCE', 325)]
# DIVORCE 100.0
#
# [('PARENTING', 320), ('WELLNESS', 13)]
# PARENTING 96.09609609609609
#
# [('BLACK VOICES', 255), ('WEIRD NEWS', 78)]
# BLACK VOICES 76.57657657657657
#
# [('MONEY', 256), ('ENVIRONMENT', 61)]
# MONEY 80.7570977917981
#
# [('STYLE', 173), ('ARTS & CULTURE', 129)]
# STYLE 57.28476821192053
#
# [('LATINO VOICES', 227), ('EDUCATION', 77)]
# LATINO VOICES 74.67105263157895
#
# [('TECH', 281), ('RELIGION', 35)]
# TECH 88.92405063291139
#
# [('TASTE', 311)]
# TASTE 100.0
#
# [('POLITICS', 263), ('IMPACT', 65)]
# POLITICS 80.1829268292683
#
# [('GOOD NEWS', 324)]
# GOOD NEWS 100.0
#
# [('CRIME', 320)]
# CRIME 100.0
#
# [('BUSINESS', 330)]
# BUSINESS 100.0
#
# [('HOME & LIVING', 330)]
# HOME & LIVING 100.0
#
# [('PARENTS', 227), ('ARTS & CULTURE', 72)]
# PARENTS 75.91973244147157
#
# [('ARTS', 318), ('FIFTY', 14)]
# ARTS 95.78313253012048
#
# [('WEDDINGS', 216), ('FOOD & DRINK', 105)]
# WEDDINGS 67.28971962616822
#
# [('TRAVEL', 248), ('MEDIA', 77)]
# TRAVEL 76.3076923076923
#
# [('SPORTS', 262), ('QUEER VOICES', 72)]
# SPORTS 78.44311377245509
#
# [('COMEDY', 258), ('WOMEN', 78)]
# COMEDY 76.78571428571429
#
# [('CRIME', 180), ('ENTERTAINMENT', 140)]
# CRIME 56.25
#
# [('WELLNESS', 335)]
# WELLNESS 100.0
#
# [('WORLD NEWS', 216), ('IMPACT', 109)]
# WORLD NEWS 66.46153846153847
#
# [('WEIRD NEWS', 331)]
# WEIRD NEWS 100.0
#
# [('MONEY', 244), ('FOOD & DRINK', 75)]
# MONEY 76.48902821316615
#
# [('RELIGION', 314)]
# RELIGION 100.0
#
# [('FIFTY', 332)]
# FIFTY 100.0
#
# [('TECH', 219), ('MEDIA', 100)]
# TECH 68.65203761755485
#
# [('BLACK VOICES', 245), ('WOMEN', 88)]
# BLACK VOICES 73.57357357357357
#
# [('WEDDINGS', 284), ('DIVORCE', 39)]
# WEDDINGS 87.92569659442725
#
# [('EDUCATION', 301)]
# EDUCATION 100.0
#
# [('LATINO VOICES', 273), ('SCIENCE', 32)]
# LATINO VOICES 89.50819672131148
#
# [('STYLE & BEAUTY', 190), ('DIVORCE', 136)]
# STYLE & BEAUTY 58.282208588957054
#
# [('PARENTS', 273), ('COLLEGE', 24)]
# PARENTS 91.91919191919192
#
# [('ENVIRONMENT', 315)]
# ENVIRONMENT 100.0
#
# [('HEALTHY LIVING', 215), ('TASTE', 99)]
# HEALTHY LIVING 68.47133757961784
#
# [('THE WORLDPOST', 320)]
# THE WORLDPOST 100.0
#
# [('GREEN', 218), ('TASTE', 90)]
# GREEN 70.77922077922078
#
# [('PARENTING', 180), ('HOME & LIVING', 152)]
# PARENTING 54.21686746987952
#
# [('IMPACT', 326)]
# IMPACT 100.0
#
# [('SCIENCE', 159), ('RELIGION', 151)]
# SCIENCE 51.29032258064516
#
# [('TRAVEL', 252), ('BUSINESS', 76)]
# TRAVEL 76.82926829268293
#
# [('WORLDPOST', 325), ('GOOD NEWS', 3)]
# WORLDPOST 99.08536585365853
#
# [('COLLEGE', 298)]
# COLLEGE 100.0
#
# [('ARTS & CULTURE', 299)]
# ARTS & CULTURE 100.0
#
# [('STYLE', 303)]
# STYLE 100.0
#
# [('ENTERTAINMENT', 321)]
# ENTERTAINMENT 100.0
#
# [('COMEDY', 242), ('QUEER VOICES', 94)]
# COMEDY 72.02380952380952
#
# [('CULTURE & ARTS', 310)]
# CULTURE & ARTS 100.0
#
# Num clust  65
# Counter({36: 338, 15: 338, 48: 336, 1: 335, 39: 334, 24: 334, 62: 333, 25: 331, 52: 330, 6: 330, 35: 328, 11: 326, 45: 324, 12: 324, 16: 321, 19: 320, 43: 320, 32: 320, 63: 320, 41: 320, 9: 319, 23: 318, 0: 318, 17: 317, 56: 317, 40: 315, 60: 315, 49: 315, 34: 315, 26: 315, 28: 313, 44: 313, 4: 312, 29: 312, 7: 312, 51: 311, 10: 311, 37: 310, 57: 310, 58: 310, 13: 310, 21: 309, 50: 309, 38: 309, 54: 308, 3: 308, 59: 308, 20: 308, 22: 308, 33: 307, 18: 307, 27: 307, 46: 307, 31: 306, 64: 306, 14: 305, 47: 305, 61: 305, 42: 305, 2: 305, 5: 305, 8: 304, 55: 304, 53: 303, 30: 302})
# [('THE WORLDPOST', 318)]
# THE WORLDPOST 100.0
#
# [('COMEDY', 335)]
# COMEDY 100.0
#
# [('DIVORCE', 235), ('STYLE & BEAUTY', 70)]
# DIVORCE 77.04918032786885
#
# [('LATINO VOICES', 308)]
# LATINO VOICES 100.0
#
# [('IMPACT', 312)]
# IMPACT 100.0
#
# [('CULTURE & ARTS', 196), ('ENVIRONMENT', 109)]
# CULTURE & ARTS 64.26229508196721
#
# [('TRAVEL', 330)]
# TRAVEL 100.0
#
# [('PARENTS', 261), ('ARTS & CULTURE', 51)]
# PARENTS 83.65384615384616
#
# [('PARENTING', 206), ('WELLNESS', 98)]
# PARENTING 67.76315789473684
#
# [('GREEN', 318), ('STYLE', 1)]
# GREEN 99.68652037617555
#
# [('FIFTY', 173), ('WORLDPOST', 138)]
# FIFTY 55.62700964630225
#
# [('WEIRD NEWS', 201), ('BLACK VOICES', 125)]
# WEIRD NEWS 61.65644171779141
#
# [('MEDIA', 208), ('TECH', 116)]
# MEDIA 64.19753086419753
#
# [('FOOD & DRINK', 310)]
# FOOD & DRINK 100.0
#
# [('ENTERTAINMENT', 305)]
# ENTERTAINMENT 100.0
#
# [('QUEER VOICES', 207), ('SPORTS', 131)]
# QUEER VOICES 61.24260355029586
#
# [('HEALTHY LIVING', 279), ('TASTE', 42)]
# HEALTHY LIVING 86.91588785046729
#
# [('RELIGION', 253), ('TECH', 64)]
# RELIGION 79.81072555205047
#
# [('HOME & LIVING', 182), ('STYLE & BEAUTY', 125)]
# HOME & LIVING 59.28338762214984
#
# [('POLITICS', 320)]
# POLITICS 100.0
#
# [('ARTS', 291), ('FIFTY', 17)]
# ARTS 94.48051948051948
#
# [('EDUCATION', 192), ('COLLEGE', 117)]
# EDUCATION 62.13592233009709
#
# [('MONEY', 224), ('ENVIRONMENT', 84)]
# MONEY 72.72727272727273
#
# [('STYLE', 318)]
# STYLE 100.0
#
# [('BUSINESS', 301), ('SPORTS', 33)]
# BUSINESS 90.11976047904191
#
# [('WOMEN', 286), ('BLACK VOICES', 45)]
# WOMEN 86.404833836858
#
# [('GOOD NEWS', 266), ('WORLDPOST', 49)]
# GOOD NEWS 84.44444444444444
#
# [('WEDDINGS', 307)]
# WEDDINGS 100.0
#
# [('SCIENCE', 313)]
# SCIENCE 100.0
#
# [('PARENTS', 239), ('COLLEGE', 73)]
# PARENTS 76.6025641025641
#
# [('CRIME', 302)]
# CRIME 100.0
#
# [('ARTS', 209), ('WELLNESS', 97)]
# ARTS 68.30065359477125
#
# [('GREEN', 182), ('TASTE', 138)]
# GREEN 56.875
#
# [('HOME & LIVING', 307)]
# HOME & LIVING 100.0
#
# [('STYLE', 181), ('ARTS & CULTURE', 134)]
# STYLE 57.46031746031746
#
# [('MEDIA', 292), ('TRAVEL', 36)]
# MEDIA 89.02439024390245
#
# [('QUEER VOICES', 293), ('COMEDY', 45)]
# QUEER VOICES 86.68639053254438
#
# [('WORLD NEWS', 282), ('IMPACT', 28)]
# WORLD NEWS 90.96774193548387
#
# [('MONEY', 276), ('FOOD & DRINK', 33)]
# MONEY 89.32038834951456
#
# [('WOMEN', 214), ('COMEDY', 120)]
# WOMEN 64.07185628742515
#
# [('IMPACT', 160), ('POLITICS', 155)]
# IMPACT 50.79365079365079
#
# [('HEALTHY LIVING', 221), ('THE WORLDPOST', 99)]
# HEALTHY LIVING 69.0625
#
# [('STYLE & BEAUTY', 305)]
# STYLE & BEAUTY 100.0
#
# [('TECH', 320)]
# TECH 100.0
#
# [('WORLDPOST', 313)]
# WORLDPOST 100.0
#
# [('WEIRD NEWS', 299), ('POLITICS', 25)]
# WEIRD NEWS 92.28395061728395
#
# [('ENVIRONMENT', 307)]
# ENVIRONMENT 100.0
#
# [('WELLNESS', 305)]
# WELLNESS 100.0
#
# [('SPORTS', 336)]
# SPORTS 100.0
#
# [('ARTS & CULTURE', 315)]
# ARTS & CULTURE 100.0
#
# [('FOOD & DRINK', 157), ('WEDDINGS', 152)]
# FOOD & DRINK 50.80906148867314
#
# [('LATINO VOICES', 192), ('SCIENCE', 119)]
# LATINO VOICES 61.736334405144696
#
# [('BLACK VOICES', 330)]
# BLACK VOICES 100.0
#
# [('CRIME', 198), ('ENTERTAINMENT', 105)]
# CRIME 65.34653465346534
#
# [('WORLD NEWS', 218), ('ENTERTAINMENT', 90)]
# WORLD NEWS 70.77922077922078
#
# [('CULTURE & ARTS', 303)]
# CULTURE & ARTS 100.0
#
# [('GOOD NEWS', 234), ('THE WORLDPOST', 83)]
# GOOD NEWS 73.81703470031546
#
# [('COLLEGE', 310)]
# COLLEGE 100.0
#
# [('FIFTY', 310)]
# FIFTY 100.0
#
# [('EDUCATION', 308)]
# EDUCATION 100.0
#
# [('RELIGION', 247), ('SCIENCE', 68)]
# RELIGION 78.41269841269842
#
# [('PARENTING', 294), ('HOME & LIVING', 11)]
# PARENTING 96.39344262295081
#
# [('BUSINESS', 199), ('TRAVEL', 134)]
# BUSINESS 59.75975975975976
#
# [('TASTE', 320)]
# TASTE 100.0
#
# [('DIVORCE', 265), ('WEDDINGS', 41)]
# DIVORCE 86.60130718954248
#
# Num clust  66
# Counter({6: 329, 12: 328, 29: 327, 43: 327, 59: 326, 20: 326, 42: 326, 25: 326, 40: 325, 54: 324, 19: 323, 2: 323, 8: 323, 51: 321, 53: 321, 48: 321, 31: 320, 10: 319, 28: 319, 63: 316, 17: 316, 5: 316, 36: 315, 50: 315, 26: 315, 22: 314, 16: 314, 41: 313, 9: 313, 13: 313, 37: 312, 47: 311, 62: 311, 57: 310, 30: 310, 3: 310, 21: 309, 1: 308, 55: 308, 44: 307, 4: 307, 38: 307, 60: 307, 15: 306, 52: 305, 46: 305, 14: 304, 24: 304, 23: 303, 58: 303, 32: 301, 61: 301, 35: 301, 45: 300, 27: 300, 0: 298, 7: 297, 49: 296, 33: 296, 39: 295, 11: 294, 64: 294, 18: 293, 56: 292, 65: 291, 34: 290})
# [('WORLDPOST', 171), ('GOOD NEWS', 127)]
# WORLDPOST 57.38255033557047
#
# [('BLACK VOICES', 194), ('WEIRD NEWS', 114)]
# BLACK VOICES 62.98701298701299
#
# [('LATINO VOICES', 275), ('SCIENCE', 48)]
# LATINO VOICES 85.13931888544892
#
# [('MONEY', 245), ('FOOD & DRINK', 65)]
# MONEY 79.03225806451613
#
# [('SPORTS', 180), ('BUSINESS', 127)]
# SPORTS 58.63192182410423
#
# [('TASTE', 316)]
# TASTE 100.0
#
# [('CRIME', 329)]
# CRIME 100.0
#
# [('HOME & LIVING', 188), ('STYLE & BEAUTY', 109)]
# HOME & LIVING 63.2996632996633
#
# [('STYLE', 323)]
# STYLE 100.0
#
# [('TECH', 181), ('MEDIA', 132)]
# TECH 57.82747603833866
#
# [('IMPACT', 319)]
# IMPACT 100.0
#
# [('PARENTING', 222), ('WELLNESS', 72)]
# PARENTING 75.51020408163265
#
# [('COLLEGE', 249), ('PARENTS', 79)]
# COLLEGE 75.91463414634147
#
# [('ENVIRONMENT', 313)]
# ENVIRONMENT 100.0
#
# [('WOMEN', 194), ('COMEDY', 110)]
# WOMEN 63.81578947368421
#
# [('WEDDINGS', 306)]
# WEDDINGS 100.0
#
# [('TASTE', 163), ('HEALTHY LIVING', 151)]
# TASTE 51.910828025477706
#
# [('RELIGION', 312), ('TECH', 4)]
# RELIGION 98.73417721518987
#
# [('FIFTY', 238), ('ARTS', 55)]
# FIFTY 81.22866894197952
#
# [('WORLD NEWS', 305), ('ENTERTAINMENT', 18)]
# WORLD NEWS 94.42724458204334
#
# [('EDUCATION', 326)]
# EDUCATION 100.0
#
# [('TRAVEL', 244), ('BUSINESS', 65)]
# TRAVEL 78.96440129449839
#
# [('POLITICS', 239), ('WEIRD NEWS', 75)]
# POLITICS 76.11464968152866
#
# [('QUEER VOICES', 288), ('SPORTS', 15)]
# QUEER VOICES 95.04950495049505
#
# [('THE WORLDPOST', 232), ('GOOD NEWS', 72)]
# THE WORLDPOST 76.3157894736842
#
# [('ARTS & CULTURE', 232), ('PARENTS', 94)]
# ARTS & CULTURE 71.16564417177914
#
# [('CULTURE & ARTS', 314)]
# CULTURE & ARTS 100.0
#
# [('DIVORCE', 209), ('STYLE & BEAUTY', 91)]
# DIVORCE 69.66666666666667
#
# [('RELIGION', 188), ('SCIENCE', 131)]
# RELIGION 58.93416927899686
#
# [('CRIME', 171), ('ENTERTAINMENT', 156)]
# CRIME 52.293577981651374
#
# [('FOOD & DRINK', 310)]
# FOOD & DRINK 100.0
#
# [('GREEN', 299), ('TASTE', 21)]
# GREEN 93.4375
#
# [('COMEDY', 301)]
# COMEDY 100.0
#
# [('HOME & LIVING', 296)]
# HOME & LIVING 100.0
#
# [('ARTS', 153), ('WELLNESS', 137)]
# ARTS 52.758620689655174
#
# [('GOOD NEWS', 301)]
# GOOD NEWS 100.0
#
# [('TECH', 315)]
# TECH 100.0
#
# [('MONEY', 255), ('ENVIRONMENT', 57)]
# MONEY 81.73076923076923
#
# [('THE WORLDPOST', 268), ('HEALTHY LIVING', 39)]
# THE WORLDPOST 87.29641693811075
#
# [('FIFTY', 262), ('WORLDPOST', 33)]
# FIFTY 88.8135593220339
#
# [('ARTS & CULTURE', 268), ('STYLE', 57)]
# ARTS & CULTURE 82.46153846153847
#
# [('MEDIA', 313)]
# MEDIA 100.0
#
# [('COLLEGE', 251), ('EDUCATION', 75)]
# COLLEGE 76.99386503067484
#
# [('PARENTS', 327)]
# PARENTS 100.0
#
# [('BLACK VOICES', 306), ('WOMEN', 1)]
# BLACK VOICES 99.6742671009772
#
# [('STYLE & BEAUTY', 300)]
# STYLE & BEAUTY 100.0
#
# [('SPORTS', 305)]
# SPORTS 100.0
#
# [('WEIRD NEWS', 311)]
# WEIRD NEWS 100.0
#
# [('GREEN', 201), ('STYLE', 120)]
# GREEN 62.61682242990654
#
# [('WORLDPOST', 296)]
# WORLDPOST 100.0
#
# [('CULTURE & ARTS', 185), ('ENVIRONMENT', 130)]
# CULTURE & ARTS 58.73015873015873
#
# [('WORLD NEWS', 195), ('IMPACT', 126)]
# WORLD NEWS 60.74766355140187
#
# [('WOMEN', 305)]
# WOMEN 100.0
#
# [('SCIENCE', 321)]
# SCIENCE 100.0
#
# [('LATINO VOICES', 225), ('EDUCATION', 99)]
# LATINO VOICES 69.44444444444444
#
# [('BUSINESS', 308)]
# BUSINESS 100.0
#
# [('ARTS', 292)]
# ARTS 100.0
#
# [('HEALTHY LIVING', 310)]
# HEALTHY LIVING 100.0
#
# [('DIVORCE', 291), ('WEDDINGS', 12)]
# DIVORCE 96.03960396039604
#
# [('ENTERTAINMENT', 326)]
# ENTERTAINMENT 100.0
#
# [('WEDDINGS', 182), ('FOOD & DRINK', 125)]
# WEDDINGS 59.28338762214984
#
# [('QUEER VOICES', 212), ('COMEDY', 89)]
# QUEER VOICES 70.43189368770764
#
# [('TRAVEL', 256), ('MEDIA', 55)]
# TRAVEL 82.31511254019293
#
# [('POLITICS', 261), ('IMPACT', 55)]
# POLITICS 82.59493670886076
#
# [('PARENTING', 278), ('HOME & LIVING', 16)]
# PARENTING 94.5578231292517
#
# [('WELLNESS', 291)]
# WELLNESS 100.0
#
# Num clust  67
# Counter({19: 326, 27: 324, 43: 323, 47: 323, 8: 323, 49: 323, 52: 323, 2: 322, 10: 321, 5: 321, 48: 321, 32: 320, 30: 320, 34: 319, 29: 319, 21: 318, 42: 318, 16: 316, 50: 316, 14: 315, 38: 314, 36: 313, 53: 313, 20: 312, 0: 311, 40: 310, 4: 310, 6: 310, 62: 310, 37: 308, 59: 308, 22: 308, 25: 308, 31: 307, 23: 306, 33: 306, 66: 305, 64: 304, 12: 304, 54: 304, 7: 303, 45: 303, 46: 302, 11: 300, 1: 300, 55: 299, 57: 298, 28: 298, 56: 298, 51: 298, 17: 297, 35: 296, 18: 295, 58: 294, 15: 294, 9: 292, 44: 291, 39: 291, 26: 288, 60: 288, 65: 288, 24: 287, 13: 286, 41: 284, 61: 284, 63: 282, 3: 282})
# [('HOME & LIVING', 311)]
# HOME & LIVING 100.0
#
# [('WOMEN', 300)]
# WOMEN 100.0
#
# [('ARTS & CULTURE', 279), ('STYLE', 43)]
# ARTS & CULTURE 86.64596273291926
#
# [('TECH', 282)]
# TECH 100.0
#
# [('ENTERTAINMENT', 310)]
# ENTERTAINMENT 100.0
#
# [('ENVIRONMENT', 321)]
# ENVIRONMENT 100.0
#
# [('GOOD NEWS', 310)]
# GOOD NEWS 100.0
#
# [('EDUCATION', 303)]
# EDUCATION 100.0
#
# [('TASTE', 323)]
# TASTE 100.0
#
# [('SPORTS', 292)]
# SPORTS 100.0
#
# [('WEDDINGS', 252), ('FOOD & DRINK', 69)]
# WEDDINGS 78.50467289719626
#
# [('POLITICS', 300)]
# POLITICS 100.0
#
# [('ARTS', 304)]
# ARTS 100.0
#
# [('TRAVEL', 214), ('MEDIA', 72)]
# TRAVEL 74.82517482517483
#
# [('STYLE & BEAUTY', 205), ('DIVORCE', 110)]
# STYLE & BEAUTY 65.07936507936508
#
# [('LATINO VOICES', 294)]
# LATINO VOICES 100.0
#
# [('PARENTS', 316)]
# PARENTS 100.0
#
# [('WEIRD NEWS', 250), ('BLACK VOICES', 47)]
# WEIRD NEWS 84.17508417508418
#
# [('QUEER VOICES', 295)]
# QUEER VOICES 100.0
#
# [('GREEN', 192), ('STYLE', 134)]
# GREEN 58.895705521472394
#
# [('CRIME', 312)]
# CRIME 100.0
#
# [('HEALTHY LIVING', 318)]
# HEALTHY LIVING 100.0
#
# [('WORLDPOST', 223), ('GOOD NEWS', 85)]
# WORLDPOST 72.40259740259741
#
# [('WORLD NEWS', 260), ('IMPACT', 46)]
# WORLD NEWS 84.9673202614379
#
# [('RELIGION', 287)]
# RELIGION 100.0
#
# [('PARENTING', 308)]
# PARENTING 100.0
#
# [('BUSINESS', 288)]
# BUSINESS 100.0
#
# [('MONEY', 216), ('FOOD & DRINK', 108)]
# MONEY 66.66666666666667
#
# [('BLACK VOICES', 298)]
# BLACK VOICES 100.0
#
# [('CULTURE & ARTS', 318)]
# CULTURE & ARTS 100.0
#
# [('WEDDINGS', 248), ('DIVORCE', 72)]
# WEDDINGS 77.5
#
# [('WELLNESS', 255), ('PARENTING', 52)]
# WELLNESS 83.06188925081433
#
# [('TASTE', 162), ('HEALTHY LIVING', 158)]
# TASTE 50.625
#
# [('WORLDPOST', 277), ('FIFTY', 29)]
# WORLDPOST 90.52287581699346
#
# [('ARTS & CULTURE', 221), ('PARENTS', 98)]
# ARTS & CULTURE 69.27899686520377
#
# [('COMEDY', 258), ('QUEER VOICES', 38)]
# COMEDY 87.16216216216216
#
# [('COLLEGE', 227), ('PARENTS', 86)]
# COLLEGE 72.52396166134186
#
# [('WORLD NEWS', 240), ('ENTERTAINMENT', 68)]
# WORLD NEWS 77.92207792207792
#
# [('STYLE & BEAUTY', 295), ('HOME & LIVING', 19)]
# STYLE & BEAUTY 93.94904458598727
#
# [('SCIENCE', 221), ('LATINO VOICES', 70)]
# SCIENCE 75.94501718213058
#
# [('CRIME', 188), ('ENTERTAINMENT', 122)]
# CRIME 60.645161290322584
#
# [('MEDIA', 284)]
# MEDIA 100.0
#
# [('DIVORCE', 318)]
# DIVORCE 100.0
#
# [('STYLE', 323)]
# STYLE 100.0
#
# [('BUSINESS', 210), ('SPORTS', 81)]
# BUSINESS 72.16494845360825
#
# [('FIFTY', 166), ('ARTS', 137)]
# FIFTY 54.78547854785479
#
# [('POLITICS', 152), ('IMPACT', 150)]
# POLITICS 50.33112582781457
#
# [('GREEN', 308), ('TASTE', 15)]
# GREEN 95.3560371517028
#
# [('CULTURE & ARTS', 181), ('ENVIRONMENT', 140)]
# CULTURE & ARTS 56.386292834890966
#
# [('FOOD & DRINK', 323)]
# FOOD & DRINK 100.0
#
# [('THE WORLDPOST', 292), ('HEALTHY LIVING', 24)]
# THE WORLDPOST 92.40506329113924
#
# [('EDUCATION', 162), ('LATINO VOICES', 136)]
# EDUCATION 54.36241610738255
#
# [('MONEY', 284), ('ENVIRONMENT', 39)]
# MONEY 87.92569659442725
#
# [('THE WORLDPOST', 208), ('GOOD NEWS', 105)]
# THE WORLDPOST 66.45367412140575
#
# [('WELLNESS', 245), ('ARTS', 59)]
# WELLNESS 80.59210526315789
#
# [('BLACK VOICES', 155), ('WOMEN', 144)]
# BLACK VOICES 51.83946488294314
#
# [('COMEDY', 242), ('WOMEN', 56)]
# COMEDY 81.20805369127517
#
# [('WEIRD NEWS', 250), ('POLITICS', 48)]
# WEIRD NEWS 83.89261744966443
#
# [('QUEER VOICES', 167), ('SPORTS', 127)]
# QUEER VOICES 56.802721088435376
#
# [('COLLEGE', 273), ('EDUCATION', 35)]
# COLLEGE 88.63636363636364
#
# [('TRAVEL', 286), ('BUSINESS', 2)]
# TRAVEL 99.30555555555556
#
# [('RELIGION', 204), ('TECH', 80)]
# RELIGION 71.83098591549296
#
# [('HOME & LIVING', 170), ('PARENTING', 140)]
# HOME & LIVING 54.83870967741935
#
# [('MEDIA', 144), ('TECH', 138)]
# MEDIA 51.06382978723404
#
# [('IMPACT', 304)]
# IMPACT 100.0
#
# [('SCIENCE', 279), ('RELIGION', 9)]
# SCIENCE 96.875
#
# [('FIFTY', 305)]
# FIFTY 100.0
#
# Num clust  68
# Counter({34: 318, 19: 317, 61: 317, 35: 315, 6: 315, 46: 314, 10: 313, 22: 311, 57: 311, 4: 311, 32: 310, 55: 309, 47: 309, 36: 309, 51: 308, 18: 308, 13: 307, 14: 306, 27: 306, 8: 306, 48: 306, 17: 306, 31: 305, 43: 305, 63: 305, 33: 305, 11: 305, 53: 304, 38: 304, 45: 304, 7: 303, 2: 303, 52: 302, 58: 302, 16: 302, 25: 302, 56: 301, 29: 301, 40: 301, 24: 300, 28: 300, 26: 300, 66: 299, 23: 299, 49: 298, 9: 298, 44: 298, 0: 297, 3: 296, 54: 296, 67: 296, 60: 296, 15: 295, 39: 295, 50: 294, 42: 293, 1: 292, 5: 292, 30: 291, 64: 290, 37: 290, 59: 289, 20: 288, 65: 287, 21: 287, 12: 287, 41: 286, 62: 285})
# [('ENVIRONMENT', 297)]
# ENVIRONMENT 100.0
#
# [('TRAVEL', 292)]
# TRAVEL 100.0
#
# [('HEALTHY LIVING', 303)]
# HEALTHY LIVING 100.0
#
# [('WORLD NEWS', 167), ('ENTERTAINMENT', 129)]
# WORLD NEWS 56.41891891891892
#
# [('PARENTING', 222), ('HOME & LIVING', 89)]
# PARENTING 71.38263665594856
#
# [('LATINO VOICES', 289), ('EDUCATION', 3)]
# LATINO VOICES 98.97260273972603
#
# [('WOMEN', 315)]
# WOMEN 100.0
#
# [('ARTS & CULTURE', 212), ('STYLE', 91)]
# ARTS & CULTURE 69.96699669966996
#
# [('FIFTY', 237), ('WORLDPOST', 69)]
# FIFTY 77.45098039215686
#
# [('FOOD & DRINK', 283), ('MONEY', 15)]
# FOOD & DRINK 94.96644295302013
#
# [('POLITICS', 313)]
# POLITICS 100.0
#
# [('STYLE & BEAUTY', 294), ('DIVORCE', 11)]
# STYLE & BEAUTY 96.39344262295081
#
# [('RELIGION', 156), ('SCIENCE', 131)]
# RELIGION 54.35540069686411
#
# [('SPORTS', 217), ('QUEER VOICES', 90)]
# SPORTS 70.68403908794788
#
# [('GREEN', 202), ('STYLE', 104)]
# GREEN 66.01307189542484
#
# [('EDUCATION', 203), ('COLLEGE', 92)]
# EDUCATION 68.8135593220339
#
# [('GOOD NEWS', 175), ('WORLDPOST', 127)]
# GOOD NEWS 57.94701986754967
#
# [('ARTS', 306)]
# ARTS 100.0
#
# [('STYLE & BEAUTY', 206), ('HOME & LIVING', 102)]
# STYLE & BEAUTY 66.88311688311688
#
# [('WEIRD NEWS', 291), ('BLACK VOICES', 26)]
# WEIRD NEWS 91.7981072555205
#
# [('CRIME', 288)]
# CRIME 100.0
#
# [('TECH', 273), ('MEDIA', 14)]
# TECH 95.1219512195122
#
# [('COMEDY', 210), ('QUEER VOICES', 101)]
# COMEDY 67.52411575562701
#
# [('CULTURE & ARTS', 298)]
# CULTURE & ARTS 100.0
#
# [('WORLD NEWS', 300)]
# WORLD NEWS 100.0
#
# [('DIVORCE', 185), ('WEDDINGS', 117)]
# DIVORCE 61.258278145695364
#
# [('PARENTS', 300)]
# PARENTS 100.0
#
# [('GREEN', 298), ('TASTE', 8)]
# GREEN 97.38562091503267
#
# [('BUSINESS', 300)]
# BUSINESS 100.0
#
# [('THE WORLDPOST', 278), ('GOOD NEWS', 23)]
# THE WORLDPOST 92.35880398671097
#
# [('LATINO VOICES', 211), ('SCIENCE', 80)]
# LATINO VOICES 72.5085910652921
#
# [('IMPACT', 272), ('WORLD NEWS', 33)]
# IMPACT 89.18032786885246
#
# [('WELLNESS', 310)]
# WELLNESS 100.0
#
# [('TASTE', 187), ('HEALTHY LIVING', 118)]
# TASTE 61.31147540983606
#
# [('BLACK VOICES', 318)]
# BLACK VOICES 100.0
#
# [('WEIRD NEWS', 209), ('POLITICS', 106)]
# WEIRD NEWS 66.34920634920636
#
# [('HOME & LIVING', 309)]
# HOME & LIVING 100.0
#
# [('MEDIA', 199), ('TRAVEL', 91)]
# MEDIA 68.62068965517241
#
# [('WORLDPOST', 304)]
# WORLDPOST 100.0
#
# [('MONEY', 189), ('ENVIRONMENT', 106)]
# MONEY 64.0677966101695
#
# [('WEDDINGS', 301)]
# WEDDINGS 100.0
#
# [('RELIGION', 286)]
# RELIGION 100.0
#
# [('ENTERTAINMENT', 293)]
# ENTERTAINMENT 100.0
#
# [('STYLE', 305)]
# STYLE 100.0
#
# [('CULTURE & ARTS', 201), ('ENVIRONMENT', 97)]
# CULTURE & ARTS 67.4496644295302
#
# [('DIVORCE', 304)]
# DIVORCE 100.0
#
# [('COMEDY', 290), ('WOMEN', 24)]
# COMEDY 92.35668789808918
#
# [('QUEER VOICES', 309)]
# QUEER VOICES 100.0
#
# [('FIFTY', 263), ('ARTS', 43)]
# FIFTY 85.94771241830065
#
# [('PARENTS', 186), ('COLLEGE', 112)]
# PARENTS 62.41610738255034
#
# [('EDUCATION', 294)]
# EDUCATION 100.0
#
# [('WELLNESS', 157), ('ARTS', 151)]
# WELLNESS 50.97402597402598
#
# [('ARTS & CULTURE', 288), ('PARENTS', 14)]
# ARTS & CULTURE 95.36423841059603
#
# [('SPORTS', 283), ('BUSINESS', 21)]
# SPORTS 93.09210526315789
#
# [('BUSINESS', 179), ('TRAVEL', 117)]
# BUSINESS 60.472972972972975
#
# [('IMPACT', 228), ('POLITICS', 81)]
# IMPACT 73.7864077669903
#
# [('THE WORLDPOST', 222), ('HEALTHY LIVING', 79)]
# THE WORLDPOST 73.75415282392026
#
# [('PARENTING', 278), ('WELLNESS', 33)]
# PARENTING 89.38906752411576
#
# [('GOOD NEWS', 302)]
# GOOD NEWS 100.0
#
# [('SCIENCE', 289)]
# SCIENCE 100.0
#
# [('MONEY', 296)]
# MONEY 100.0
#
# [('WOMEN', 161), ('BLACK VOICES', 156)]
# WOMEN 50.78864353312303
#
# [('TECH', 227), ('RELIGION', 58)]
# TECH 79.64912280701755
#
# [('TASTE', 305)]
# TASTE 100.0
#
# [('CRIME', 212), ('ENTERTAINMENT', 78)]
# CRIME 73.10344827586206
#
# [('MEDIA', 287)]
# MEDIA 100.0
#
# [('FOOD & DRINK', 217), ('WEDDINGS', 82)]
# FOOD & DRINK 72.5752508361204
#
# [('COLLEGE', 296)]
# COLLEGE 100.0
#
# Num clust  69
# Counter({10: 317, 32: 316, 37: 315, 57: 314, 19: 314, 20: 313, 51: 312, 31: 312, 2: 311, 44: 310, 65: 310, 29: 308, 4: 308, 62: 306, 26: 305, 13: 305, 59: 305, 18: 304, 47: 304, 48: 303, 5: 303, 58: 303, 30: 303, 11: 301, 64: 301, 23: 301, 61: 301, 38: 300, 17: 300, 39: 300, 53: 299, 7: 299, 8: 298, 28: 298, 67: 297, 16: 297, 34: 297, 15: 297, 41: 296, 50: 296, 43: 296, 22: 294, 42: 294, 12: 294, 3: 294, 46: 293, 49: 292, 68: 292, 0: 291, 55: 291, 21: 290, 45: 290, 6: 288, 27: 288, 56: 286, 33: 286, 52: 286, 54: 285, 9: 284, 25: 283, 40: 283, 1: 282, 24: 282, 36: 281, 60: 280, 63: 280, 14: 279, 35: 279, 66: 278})
# [('CRIME', 291)]
# CRIME 100.0
#
# [('GOOD NEWS', 211), ('WORLDPOST', 71)]
# GOOD NEWS 74.822695035461
#
# [('TRAVEL', 311)]
# TRAVEL 100.0
#
# [('WEDDINGS', 294)]
# WEDDINGS 100.0
#
# [('EDUCATION', 308)]
# EDUCATION 100.0
#
# [('WOMEN', 303)]
# WOMEN 100.0
#
# [('STYLE', 245), ('GREEN', 43)]
# STYLE 85.06944444444444
#
# [('PARENTING', 299)]
# PARENTING 100.0
#
# [('IMPACT', 269), ('WORLD NEWS', 29)]
# IMPACT 90.26845637583892
#
# [('ENVIRONMENT', 284)]
# ENVIRONMENT 100.0
#
# [('RELIGION', 317)]
# RELIGION 100.0
#
# [('POLITICS', 301)]
# POLITICS 100.0
#
# [('ARTS', 277), ('WELLNESS', 17)]
# ARTS 94.21768707482993
#
# [('QUEER VOICES', 206), ('SPORTS', 99)]
# QUEER VOICES 67.54098360655738
#
# [('HEALTHY LIVING', 279)]
# HEALTHY LIVING 100.0
#
# [('DIVORCE', 297)]
# DIVORCE 100.0
#
# [('ARTS & CULTURE', 169), ('PARENTS', 128)]
# ARTS & CULTURE 56.9023569023569
#
# [('HOME & LIVING', 290), ('STYLE & BEAUTY', 10)]
# HOME & LIVING 96.66666666666667
#
# [('WEIRD NEWS', 304)]
# WEIRD NEWS 100.0
#
# [('SCIENCE', 279), ('LATINO VOICES', 35)]
# SCIENCE 88.85350318471338
#
# [('MEDIA', 313)]
# MEDIA 100.0
#
# [('FIFTY', 290)]
# FIFTY 100.0
#
# [('ENTERTAINMENT', 294)]
# ENTERTAINMENT 100.0
#
# [('COMEDY', 301)]
# COMEDY 100.0
#
# [('CULTURE & ARTS', 281)]
# CULTURE & ARTS 100.0
#
# [('GREEN', 171), ('TASTE', 112)]
# GREEN 60.42402826855124
#
# [('BLACK VOICES', 282), ('WEIRD NEWS', 23)]
# BLACK VOICES 92.45901639344262
#
# [('MONEY', 288)]
# MONEY 100.0
#
# [('STYLE & BEAUTY', 190), ('DIVORCE', 108)]
# STYLE & BEAUTY 63.758389261744966
#
# [('BUSINESS', 213), ('SPORTS', 95)]
# BUSINESS 69.15584415584415
#
# [('COLLEGE', 230), ('PARENTS', 73)]
# COLLEGE 75.9075907590759
#
# [('LATINO VOICES', 312)]
# LATINO VOICES 100.0
#
# [('TECH', 227), ('RELIGION', 89)]
# TECH 71.83544303797468
#
# [('WORLDPOST', 144), ('FIFTY', 142)]
# WORLDPOST 50.34965034965035
#
# [('WELLNESS', 187), ('PARENTING', 110)]
# WELLNESS 62.96296296296296
#
# [('THE WORLDPOST', 270), ('GOOD NEWS', 9)]
# THE WORLDPOST 96.7741935483871
#
# [('TASTE', 281)]
# TASTE 100.0
#
# [('SCIENCE', 221), ('RELIGION', 94)]
# SCIENCE 70.15873015873017
#
# [('IMPACT', 231), ('POLITICS', 69)]
# IMPACT 77.0
#
# [('STYLE & BEAUTY', 300)]
# STYLE & BEAUTY 100.0
#
# [('CULTURE & ARTS', 218), ('ENVIRONMENT', 65)]
# CULTURE & ARTS 77.03180212014134
#
# [('WORLD NEWS', 174), ('ENTERTAINMENT', 122)]
# WORLD NEWS 58.78378378378378
#
# [('ARTS & CULTURE', 294)]
# ARTS & CULTURE 100.0
#
# [('WEDDINGS', 201), ('DIVORCE', 95)]
# WEDDINGS 67.9054054054054
#
# [('BUSINESS', 287), ('TRAVEL', 23)]
# BUSINESS 92.58064516129032
#
# [('FOOD & DRINK', 213), ('MONEY', 77)]
# FOOD & DRINK 73.44827586206897
#
# [('CRIME', 209), ('ENTERTAINMENT', 84)]
# CRIME 71.33105802047781
#
# [('BLACK VOICES', 218), ('WOMEN', 86)]
# BLACK VOICES 71.71052631578948
#
# [('WEIRD NEWS', 173), ('POLITICS', 130)]
# WEIRD NEWS 57.0957095709571
#
# [('STYLE', 255), ('ARTS & CULTURE', 37)]
# STYLE 87.32876712328768
#
# [('WELLNESS', 296)]
# WELLNESS 100.0
#
# [('TRAVEL', 166), ('MEDIA', 146)]
# TRAVEL 53.205128205128204
#
# [('ENVIRONMENT', 151), ('MONEY', 135)]
# ENVIRONMENT 52.7972027972028
#
# [('PARENTS', 299)]
# PARENTS 100.0
#
# [('WORLDPOST', 285)]
# WORLDPOST 100.0
#
# [('ARTS', 223), ('FIFTY', 68)]
# ARTS 76.63230240549828
#
# [('GREEN', 286)]
# GREEN 100.0
#
# [('TECH', 273), ('MEDIA', 41)]
# TECH 86.94267515923566
#
# [('QUEER VOICES', 294), ('COMEDY', 9)]
# QUEER VOICES 97.02970297029702
#
# [('COLLEGE', 270), ('EDUCATION', 35)]
# COLLEGE 88.52459016393442
#
# [('HEALTHY LIVING', 173), ('TASTE', 107)]
# HEALTHY LIVING 61.785714285714285
#
# [('HOME & LIVING', 210), ('PARENTING', 91)]
# HOME & LIVING 69.76744186046511
#
# [('SPORTS', 306)]
# SPORTS 100.0
#
# [('GOOD NEWS', 280)]
# GOOD NEWS 100.0
#
# [('COMEDY', 190), ('WOMEN', 111)]
# COMEDY 63.12292358803987
#
# [('EDUCATION', 157), ('LATINO VOICES', 153)]
# EDUCATION 50.645161290322584
#
# [('THE WORLDPOST', 230), ('HEALTHY LIVING', 48)]
# THE WORLDPOST 82.73381294964028
#
# [('WORLD NEWS', 297)]
# WORLD NEWS 100.0
#
# [('FOOD & DRINK', 287), ('WEDDINGS', 5)]
# FOOD & DRINK 98.28767123287672
#
# Num clust  70
# Counter({12: 313, 30: 313, 46: 312, 38: 311, 4: 310, 48: 310, 61: 308, 26: 308, 20: 307, 7: 305, 35: 305, 31: 304, 41: 302, 9: 302, 16: 300, 47: 300, 52: 298, 57: 298, 33: 298, 15: 298, 69: 297, 21: 297, 10: 296, 25: 295, 17: 295, 37: 295, 43: 294, 11: 294, 56: 294, 42: 294, 59: 293, 53: 293, 64: 293, 27: 293, 6: 293, 24: 292, 18: 291, 28: 291, 22: 291, 29: 291, 66: 291, 2: 291, 58: 291, 67: 291, 36: 290, 50: 290, 49: 290, 60: 290, 1: 290, 32: 290, 40: 289, 39: 289, 63: 288, 0: 288, 8: 288, 51: 288, 5: 287, 54: 287, 14: 287, 45: 287, 65: 287, 19: 286, 23: 285, 68: 280, 3: 275, 55: 271, 44: 268, 13: 266, 62: 264, 34: 262})
# [('BLACK VOICES', 199), ('WEIRD NEWS', 89)]
# BLACK VOICES 69.09722222222223
#
# [('FIFTY', 290)]
# FIFTY 100.0
#
# [('TECH', 243), ('MEDIA', 48)]
# TECH 83.50515463917526
#
# [('MONEY', 169), ('FOOD & DRINK', 106)]
# MONEY 61.45454545454545
#
# [('STYLE', 294), ('GREEN', 16)]
# STYLE 94.83870967741936
#
# [('CRIME', 287)]
# CRIME 100.0
#
# [('DIVORCE', 251), ('STYLE & BEAUTY', 42)]
# DIVORCE 85.66552901023891
#
# [('EDUCATION', 305)]
# EDUCATION 100.0
#
# [('SPORTS', 276), ('BUSINESS', 12)]
# SPORTS 95.83333333333333
#
# [('HEALTHY LIVING', 240), ('TASTE', 62)]
# HEALTHY LIVING 79.47019867549669
#
# [('WELLNESS', 296)]
# WELLNESS 100.0
#
# [('IMPACT', 257), ('POLITICS', 37)]
# IMPACT 87.41496598639456
#
# [('PARENTS', 232), ('ARTS & CULTURE', 81)]
# PARENTS 74.12140575079871
#
# [('ENVIRONMENT', 266)]
# ENVIRONMENT 100.0
#
# [('WOMEN', 273), ('BLACK VOICES', 14)]
# WOMEN 95.1219512195122
#
# [('HOME & LIVING', 298)]
# HOME & LIVING 100.0
#
# [('SCIENCE', 300)]
# SCIENCE 100.0
#
# [('THE WORLDPOST', 163), ('GOOD NEWS', 132)]
# THE WORLDPOST 55.25423728813559
#
# [('WORLD NEWS', 156), ('ENTERTAINMENT', 135)]
# WORLD NEWS 53.608247422680414
#
# [('BUSINESS', 201), ('TRAVEL', 85)]
# BUSINESS 70.27972027972028
#
# [('GREEN', 174), ('TASTE', 133)]
# GREEN 56.67752442996743
#
# [('STYLE & BEAUTY', 163), ('HOME & LIVING', 134)]
# STYLE & BEAUTY 54.88215488215488
#
# [('COMEDY', 148), ('QUEER VOICES', 143)]
# COMEDY 50.85910652920962
#
# [('WEDDINGS', 171), ('FOOD & DRINK', 114)]
# WEDDINGS 60.0
#
# [('WORLDPOST', 217), ('GOOD NEWS', 75)]
# WORLDPOST 74.31506849315069
#
# [('RELIGION', 295)]
# RELIGION 100.0
#
# [('COLLEGE', 308)]
# COLLEGE 100.0
#
# [('ARTS', 293)]
# ARTS 100.0
#
# [('POLITICS', 170), ('WEIRD NEWS', 121)]
# POLITICS 58.419243986254294
#
# [('QUEER VOICES', 291)]
# QUEER VOICES 100.0
#
# [('ARTS & CULTURE', 313)]
# ARTS & CULTURE 100.0
#
# [('LATINO VOICES', 268), ('EDUCATION', 36)]
# LATINO VOICES 88.15789473684211
#
# [('DIVORCE', 249), ('WEDDINGS', 41)]
# DIVORCE 85.86206896551724
#
# [('PARENTING', 230), ('HOME & LIVING', 68)]
# PARENTING 77.18120805369128
#
# [('CULTURE & ARTS', 261)]
# CULTURE & ARTS 100.0
#
# [('TASTE', 305)]
# TASTE 100.0
#
# [('ENTERTAINMENT', 290)]
# ENTERTAINMENT 100.0
#
# [('STYLE & BEAUTY', 295)]
# STYLE & BEAUTY 100.0
#
# [('PARENTS', 268), ('COLLEGE', 43)]
# PARENTS 86.17363344051446
#
# [('MEDIA', 161), ('TRAVEL', 128)]
# MEDIA 55.70934256055364
#
# [('WOMEN', 227), ('COMEDY', 62)]
# WOMEN 78.54671280276817
#
# [('LATINO VOICES', 232), ('SCIENCE', 70)]
# LATINO VOICES 76.82119205298014
#
# [('WELLNESS', 176), ('ARTS', 118)]
# WELLNESS 59.863945578231295
#
# [('IMPACT', 243), ('WORLD NEWS', 51)]
# IMPACT 82.65306122448979
#
# [('ENVIRONMENT', 208), ('MONEY', 60)]
# ENVIRONMENT 77.61194029850746
#
# [('BUSINESS', 287)]
# BUSINESS 100.0
#
# [('STYLE', 206), ('ARTS & CULTURE', 106)]
# STYLE 66.02564102564102
#
# [('HEALTHY LIVING', 260), ('THE WORLDPOST', 40)]
# HEALTHY LIVING 86.66666666666667
#
# [('GREEN', 310)]
# GREEN 100.0
#
# [('COMEDY', 290)]
# COMEDY 100.0
#
# [('WEIRD NEWS', 290)]
# WEIRD NEWS 100.0
#
# [('WEDDINGS', 288)]
# WEDDINGS 100.0
#
# [('RELIGION', 168), ('SCIENCE', 130)]
# RELIGION 56.375838926174495
#
# [('POLITICS', 293)]
# POLITICS 100.0
#
# [('BLACK VOICES', 287)]
# BLACK VOICES 100.0
#
# [('MONEY', 271)]
# MONEY 100.0
#
# [('TECH', 257), ('RELIGION', 37)]
# TECH 87.41496598639456
#
# [('PARENTING', 270), ('WELLNESS', 28)]
# PARENTING 90.60402684563758
#
# [('WORLDPOST', 283), ('FIFTY', 8)]
# WORLDPOST 97.2508591065292
#
# [('WORLD NEWS', 293)]
# WORLD NEWS 100.0
#
# [('SPORTS', 224), ('QUEER VOICES', 66)]
# SPORTS 77.24137931034483
#
# [('EDUCATION', 159), ('COLLEGE', 149)]
# EDUCATION 51.62337662337662
#
# [('CULTURE & ARTS', 238), ('ENVIRONMENT', 26)]
# CULTURE & ARTS 90.15151515151516
#
# [('CRIME', 213), ('ENTERTAINMENT', 75)]
# CRIME 73.95833333333333
#
# [('GOOD NEWS', 293)]
# GOOD NEWS 100.0
#
# [('TRAVEL', 287)]
# TRAVEL 100.0
#
# [('MEDIA', 291)]
# MEDIA 100.0
#
# [('FIFTY', 202), ('ARTS', 89)]
# FIFTY 69.41580756013745
#
# [('FOOD & DRINK', 280)]
# FOOD & DRINK 100.0
#
# [('THE WORLDPOST', 297)]
# THE WORLDPOST 100.0
#
# Num clust  71
# Counter({18: 309, 35: 309, 1: 308, 38: 306, 52: 305, 34: 305, 20: 303, 10: 302, 57: 299, 9: 298, 58: 298, 21: 297, 43: 296, 36: 296, 22: 295, 59: 295, 32: 294, 37: 294, 55: 293, 16: 293, 33: 293, 4: 292, 8: 291, 65: 291, 42: 290, 63: 290, 41: 289, 48: 289, 6: 289, 61: 289, 17: 288, 50: 288, 5: 288, 47: 288, 24: 288, 26: 287, 46: 287, 0: 287, 69: 287, 66: 286, 28: 286, 12: 286, 64: 285, 62: 285, 51: 285, 23: 285, 53: 285, 25: 284, 31: 284, 14: 284, 54: 284, 7: 284, 13: 283, 44: 283, 30: 283, 49: 282, 40: 282, 29: 282, 45: 281, 2: 280, 60: 280, 3: 280, 70: 280, 67: 279, 11: 279, 19: 278, 27: 278, 68: 276, 39: 276, 56: 275, 15: 274})
# [('RELIGION', 287)]
# RELIGION 100.0
#
# [('STYLE & BEAUTY', 190), ('DIVORCE', 118)]
# STYLE & BEAUTY 61.688311688311686
#
# [('POLITICS', 191), ('WEIRD NEWS', 89)]
# POLITICS 68.21428571428571
#
# [('HEALTHY LIVING', 163), ('TASTE', 117)]
# HEALTHY LIVING 58.214285714285715
#
# [('QUEER VOICES', 292)]
# QUEER VOICES 100.0
#
# [('COLLEGE', 193), ('PARENTS', 95)]
# COLLEGE 67.01388888888889
#
# [('ARTS', 188), ('FIFTY', 101)]
# ARTS 65.05190311418686
#
# [('MONEY', 284)]
# MONEY 100.0
#
# [('ENTERTAINMENT', 291)]
# ENTERTAINMENT 100.0
#
# [('BUSINESS', 238), ('TRAVEL', 60)]
# BUSINESS 79.86577181208054
#
# [('WELLNESS', 221), ('PARENTING', 81)]
# WELLNESS 73.17880794701986
#
# [('GOOD NEWS', 228), ('WORLDPOST', 51)]
# GOOD NEWS 81.72043010752688
#
# [('STYLE', 253), ('GREEN', 33)]
# STYLE 88.46153846153847
#
# [('BLACK VOICES', 283)]
# BLACK VOICES 100.0
#
# [('LATINO VOICES', 284)]
# LATINO VOICES 100.0
#
# [('CULTURE & ARTS', 273)]
# CULTURE & ARTS 100.0
#
# [('MEDIA', 293)]
# MEDIA 100.0
#
# [('WORLD NEWS', 288)]
# WORLD NEWS 100.0
#
# [('HOME & LIVING', 308), ('STYLE & BEAUTY', 1)]
# HOME & LIVING 99.67637540453075
#
# [('THE WORLDPOST', 220), ('HEALTHY LIVING', 58)]
# THE WORLDPOST 79.13669064748201
#
# [('WEDDINGS', 226), ('DIVORCE', 77)]
# WEDDINGS 74.58745874587459
#
# [('BUSINESS', 262), ('SPORTS', 35)]
# BUSINESS 88.21548821548822
#
# [('CRIME', 295)]
# CRIME 100.0
#
# [('GREEN', 285)]
# GREEN 100.0
#
# [('ARTS & CULTURE', 171), ('PARENTS', 117)]
# ARTS & CULTURE 59.375
#
# [('IMPACT', 257), ('POLITICS', 27)]
# IMPACT 90.49295774647888
#
# [('WOMEN', 281), ('COMEDY', 6)]
# WOMEN 97.90940766550523
#
# [('ENVIRONMENT', 278)]
# ENVIRONMENT 100.0
#
# [('EDUCATION', 267), ('COLLEGE', 19)]
# EDUCATION 93.35664335664336
#
# [('TASTE', 282)]
# TASTE 100.0
#
# [('WORLDPOST', 169), ('FIFTY', 114)]
# WORLDPOST 59.71731448763251
#
# [('SCIENCE', 284)]
# SCIENCE 100.0
#
# [('SPORTS', 169), ('QUEER VOICES', 125)]
# SPORTS 57.48299319727891
#
# [('ARTS', 293)]
# ARTS 100.0
#
# [('DIVORCE', 305)]
# DIVORCE 100.0
#
# [('STYLE & BEAUTY', 309)]
# STYLE & BEAUTY 100.0
#
# [('TRAVEL', 296)]
# TRAVEL 100.0
#
# [('FOOD & DRINK', 294)]
# FOOD & DRINK 100.0
#
# [('HOME & LIVING', 192), ('PARENTING', 114)]
# HOME & LIVING 62.745098039215684
#
# [('GOOD NEWS', 272), ('THE WORLDPOST', 4)]
# GOOD NEWS 98.55072463768116
#
# [('BLACK VOICES', 151), ('WEIRD NEWS', 131)]
# BLACK VOICES 53.54609929078014
#
# [('TECH', 265), ('RELIGION', 24)]
# TECH 91.6955017301038
#
# [('WORLD NEWS', 169), ('ENTERTAINMENT', 121)]
# WORLD NEWS 58.275862068965516
#
# [('SPORTS', 296)]
# SPORTS 100.0
#
# [('GREEN', 182), ('TASTE', 101)]
# GREEN 64.31095406360424
#
# [('ENVIRONMENT', 173), ('MONEY', 108)]
# ENVIRONMENT 61.56583629893238
#
# [('COMEDY', 287)]
# COMEDY 100.0
#
# [('PARENTS', 288)]
# PARENTS 100.0
#
# [('ARTS & CULTURE', 289)]
# ARTS & CULTURE 100.0
#
# [('POLITICS', 282)]
# POLITICS 100.0
#
# [('COLLEGE', 288)]
# COLLEGE 100.0
#
# [('LATINO VOICES', 165), ('SCIENCE', 120)]
# LATINO VOICES 57.89473684210526
#
# [('PARENTING', 305)]
# PARENTING 100.0
#
# [('FIFTY', 285)]
# FIFTY 100.0
#
# [('EDUCATION', 233), ('LATINO VOICES', 51)]
# EDUCATION 82.04225352112677
#
# [('CRIME', 205), ('ENTERTAINMENT', 88)]
# CRIME 69.96587030716724
#
# [('CULTURE & ARTS', 226), ('ENVIRONMENT', 49)]
# CULTURE & ARTS 82.18181818181819
#
# [('WEDDINGS', 274), ('FOOD & DRINK', 25)]
# WEDDINGS 91.63879598662207
#
# [('WELLNESS', 279), ('ARTS', 19)]
# WELLNESS 93.6241610738255
#
# [('MEDIA', 151), ('TRAVEL', 144)]
# MEDIA 51.186440677966104
#
# [('WEIRD NEWS', 280)]
# WEIRD NEWS 100.0
#
# [('FOOD & DRINK', 181), ('MONEY', 108)]
# FOOD & DRINK 62.62975778546713
#
# [('RELIGION', 189), ('SCIENCE', 96)]
# RELIGION 66.3157894736842
#
# [('COMEDY', 207), ('QUEER VOICES', 83)]
# COMEDY 71.37931034482759
#
# [('WOMEN', 219), ('BLACK VOICES', 66)]
# WOMEN 76.84210526315789
#
# [('TECH', 235), ('MEDIA', 56)]
# TECH 80.75601374570446
#
# [('IMPACT', 243), ('WORLD NEWS', 43)]
# IMPACT 84.96503496503496
#
# [('HEALTHY LIVING', 279)]
# HEALTHY LIVING 100.0
#
# [('THE WORLDPOST', 276)]
# THE WORLDPOST 100.0
#
# [('STYLE', 247), ('ARTS & CULTURE', 40)]
# STYLE 86.06271777003484
#
# [('WORLDPOST', 280)]
# WORLDPOST 100.0
#
# Num clust  72
# Counter({1: 304, 42: 304, 27: 303, 44: 302, 20: 301, 24: 301, 66: 300, 41: 299, 11: 299, 59: 298, 0: 297, 33: 297, 9: 296, 34: 296, 35: 296, 57: 295, 19: 295, 60: 294, 63: 294, 45: 294, 6: 293, 32: 292, 12: 292, 10: 292, 18: 290, 61: 290, 46: 290, 54: 289, 64: 288, 29: 288, 26: 288, 22: 288, 50: 287, 15: 286, 7: 286, 38: 285, 47: 285, 68: 284, 71: 284, 70: 284, 37: 283, 5: 282, 23: 282, 30: 282, 39: 281, 14: 281, 51: 279, 69: 279, 48: 279, 4: 279, 16: 278, 3: 277, 25: 277, 62: 277, 55: 276, 40: 276, 67: 275, 49: 275, 31: 274, 65: 273, 8: 272, 21: 271, 43: 270, 52: 270, 17: 268, 13: 268, 56: 267, 58: 266, 28: 265, 36: 265, 53: 264, 2: 263})
# [('WELLNESS', 208), ('ARTS', 89)]
# WELLNESS 70.03367003367003
#
# [('MEDIA', 266), ('TRAVEL', 38)]
# MEDIA 87.5
#
# [('CRIME', 263)]
# CRIME 100.0
#
# [('STYLE', 277)]
# STYLE 100.0
#
# [('WEDDINGS', 171), ('FOOD & DRINK', 108)]
# WEDDINGS 61.29032258064516
#
# [('BLACK VOICES', 251), ('WOMEN', 31)]
# BLACK VOICES 89.00709219858156
#
# [('EDUCATION', 157), ('LATINO VOICES', 136)]
# EDUCATION 53.58361774744027
#
# [('GOOD NEWS', 164), ('THE WORLDPOST', 122)]
# GOOD NEWS 57.34265734265734
#
# [('IMPACT', 272)]
# IMPACT 100.0
#
# [('SPORTS', 236), ('BUSINESS', 60)]
# SPORTS 79.72972972972973
#
# [('STYLE & BEAUTY', 184), ('HOME & LIVING', 108)]
# STYLE & BEAUTY 63.013698630136986
#
# [('SCIENCE', 273), ('RELIGION', 26)]
# SCIENCE 91.30434782608695
#
# [('FIFTY', 292)]
# FIFTY 100.0
#
# [('ENVIRONMENT', 268)]
# ENVIRONMENT 100.0
#
# [('HEALTHY LIVING', 281)]
# HEALTHY LIVING 100.0
#
# [('COLLEGE', 266), ('PARENTS', 20)]
# COLLEGE 93.00699300699301
#
# [('WEIRD NEWS', 278)]
# WEIRD NEWS 100.0
#
# [('WORLD NEWS', 268)]
# WORLD NEWS 100.0
#
# [('QUEER VOICES', 178), ('COMEDY', 112)]
# QUEER VOICES 61.37931034482759
#
# [('PARENTING', 197), ('HOME & LIVING', 98)]
# PARENTING 66.77966101694915
#
# [('TRAVEL', 160), ('BUSINESS', 141)]
# TRAVEL 53.15614617940199
#
# [('MONEY', 271)]
# MONEY 100.0
#
# [('DIVORCE', 262), ('STYLE & BEAUTY', 26)]
# DIVORCE 90.97222222222223
#
# [('PARENTS', 196), ('ARTS & CULTURE', 86)]
# PARENTS 69.50354609929079
#
# [('RELIGION', 174), ('TECH', 127)]
# RELIGION 57.80730897009967
#
# [('TASTE', 251), ('GREEN', 26)]
# TASTE 90.61371841155234
#
# [('WORLDPOST', 239), ('GOOD NEWS', 49)]
# WORLDPOST 82.98611111111111
#
# [('TECH', 303)]
# TECH 100.0
#
# [('ENTERTAINMENT', 265)]
# ENTERTAINMENT 100.0
#
# [('COLLEGE', 234), ('EDUCATION', 54)]
# COLLEGE 81.25
#
# [('WEDDINGS', 282)]
# WEDDINGS 100.0
#
# [('POLITICS', 274)]
# POLITICS 100.0
#
# [('QUEER VOICES', 292)]
# QUEER VOICES 100.0
#
# [('PARENTING', 297)]
# PARENTING 100.0
#
# [('SCIENCE', 227), ('LATINO VOICES', 69)]
# SCIENCE 76.6891891891892
#
# [('ARTS', 296)]
# ARTS 100.0
#
# [('CULTURE & ARTS', 264)]
# CULTURE & ARTS 100.0
#
# [('HEALTHY LIVING', 189), ('THE WORLDPOST', 94)]
# HEALTHY LIVING 66.7844522968198
#
# [('WOMEN', 185), ('COMEDY', 100)]
# WOMEN 64.91228070175438
#
# [('ARTS & CULTURE', 281)]
# ARTS & CULTURE 100.0
#
# [('GREEN', 276)]
# GREEN 100.0
#
# [('BUSINESS', 299)]
# BUSINESS 100.0
#
# [('MEDIA', 234), ('TECH', 70)]
# MEDIA 76.97368421052632
#
# [('WORLD NEWS', 173), ('IMPACT', 97)]
# WORLD NEWS 64.07407407407408
#
# [('TRAVEL', 302)]
# TRAVEL 100.0
#
# [('HOME & LIVING', 294)]
# HOME & LIVING 100.0
#
# [('STYLE & BEAUTY', 290)]
# STYLE & BEAUTY 100.0
#
# [('DIVORCE', 238), ('WEDDINGS', 47)]
# DIVORCE 83.50877192982456
#
# [('TASTE', 249), ('HEALTHY LIVING', 30)]
# TASTE 89.24731182795699
#
# [('MONEY', 160), ('FOOD & DRINK', 115)]
# MONEY 58.18181818181818
#
# [('GOOD NEWS', 287)]
# GOOD NEWS 100.0
#
# [('BLACK VOICES', 249), ('WEIRD NEWS', 30)]
# BLACK VOICES 89.24731182795699
#
# [('ENVIRONMENT', 201), ('MONEY', 69)]
# ENVIRONMENT 74.44444444444444
#
# [('CRIME', 237), ('ENTERTAINMENT', 27)]
# CRIME 89.77272727272727
#
# [('EDUCATION', 289)]
# EDUCATION 100.0
#
# [('WEIRD NEWS', 192), ('POLITICS', 84)]
# WEIRD NEWS 69.56521739130434
#
# [('ENTERTAINMENT', 208), ('WORLD NEWS', 59)]
# ENTERTAINMENT 77.90262172284645
#
# [('LATINO VOICES', 295)]
# LATINO VOICES 100.0
#
# [('CULTURE & ARTS', 235), ('ENVIRONMENT', 31)]
# CULTURE & ARTS 88.34586466165413
#
# [('WELLNESS', 292), ('PARENTING', 6)]
# WELLNESS 97.98657718120805
#
# [('SPORTS', 264), ('QUEER VOICES', 30)]
# SPORTS 89.79591836734694
#
# [('WORLDPOST', 261), ('FIFTY', 29)]
# WORLDPOST 90.0
#
# [('FOOD & DRINK', 277)]
# FOOD & DRINK 100.0
#
# [('FIFTY', 179), ('ARTS', 115)]
# FIFTY 60.8843537414966
#
# [('COMEDY', 288)]
# COMEDY 100.0
#
# [('POLITICS', 142), ('IMPACT', 131)]
# POLITICS 52.014652014652015
#
# [('RELIGION', 300)]
# RELIGION 100.0
#
# [('GREEN', 198), ('STYLE', 77)]
# GREEN 72.0
#
# [('WOMEN', 284)]
# WOMEN 100.0
#
# [('STYLE', 146), ('ARTS & CULTURE', 133)]
# STYLE 52.32974910394265
#
# [('THE WORLDPOST', 284)]
# THE WORLDPOST 100.0
#
# [('PARENTS', 284)]
# PARENTS 100.0
#
# Num clust  73
# Counter({41: 295, 52: 295, 10: 294, 47: 292, 20: 292, 37: 292, 28: 291, 13: 291, 51: 291, 26: 290, 40: 290, 22: 290, 33: 289, 32: 289, 16: 288, 5: 288, 0: 288, 6: 288, 11: 288, 64: 288, 63: 287, 65: 287, 54: 287, 61: 286, 62: 286, 53: 286, 44: 285, 36: 285, 1: 285, 27: 284, 24: 284, 29: 284, 49: 284, 8: 283, 15: 283, 66: 283, 3: 283, 60: 283, 14: 282, 42: 282, 72: 282, 7: 282, 18: 282, 57: 281, 35: 280, 34: 280, 38: 280, 46: 278, 55: 278, 71: 278, 31: 278, 21: 277, 48: 277, 19: 276, 70: 275, 25: 275, 9: 275, 45: 272, 58: 272, 67: 272, 12: 271, 43: 271, 2: 269, 17: 269, 50: 268, 69: 268, 39: 267, 30: 266, 59: 265, 4: 262, 56: 261, 23: 258, 68: 257})
# [('TECH', 179), ('RELIGION', 109)]
# TECH 62.15277777777778
#
# [('PARENTING', 285)]
# PARENTING 100.0
#
# [('POLITICS', 253), ('WEIRD NEWS', 16)]
# POLITICS 94.05204460966543
#
# [('GREEN', 283)]
# GREEN 100.0
#
# [('ENVIRONMENT', 224), ('MONEY', 38)]
# ENVIRONMENT 85.49618320610686
#
# [('SPORTS', 271), ('QUEER VOICES', 17)]
# SPORTS 94.09722222222223
#
# [('COLLEGE', 288)]
# COLLEGE 100.0
#
# [('GOOD NEWS', 282)]
# GOOD NEWS 100.0
#
# [('WORLD NEWS', 143), ('ENTERTAINMENT', 140)]
# WORLD NEWS 50.53003533568904
#
# [('DIVORCE', 157), ('WEDDINGS', 118)]
# DIVORCE 57.09090909090909
#
# [('MEDIA', 239), ('TRAVEL', 55)]
# MEDIA 81.29251700680273
#
# [('FIFTY', 288)]
# FIFTY 100.0
#
# [('BLACK VOICES', 182), ('WOMEN', 89)]
# BLACK VOICES 67.15867158671587
#
# [('ARTS & CULTURE', 258), ('PARENTS', 33)]
# ARTS & CULTURE 88.65979381443299
#
# [('LATINO VOICES', 246), ('SCIENCE', 36)]
# LATINO VOICES 87.23404255319149
#
# [('QUEER VOICES', 197), ('COMEDY', 86)]
# QUEER VOICES 69.6113074204947
#
# [('CRIME', 288)]
# CRIME 100.0
#
# [('FOOD & DRINK', 269)]
# FOOD & DRINK 100.0
#
# [('HOME & LIVING', 275), ('STYLE & BEAUTY', 7)]
# HOME & LIVING 97.51773049645391
#
# [('HEALTHY LIVING', 259), ('THE WORLDPOST', 17)]
# HEALTHY LIVING 93.84057971014492
#
# [('BUSINESS', 292)]
# BUSINESS 100.0
#
# [('IMPACT', 200), ('WORLD NEWS', 77)]
# IMPACT 72.20216606498195
#
# [('WELLNESS', 290)]
# WELLNESS 100.0
#
# [('CULTURE & ARTS', 243), ('ENVIRONMENT', 15)]
# CULTURE & ARTS 94.18604651162791
#
# [('STYLE', 166), ('GREEN', 118)]
# STYLE 58.45070422535211
#
# [('WOMEN', 139), ('COMEDY', 136)]
# WOMEN 50.54545454545455
#
# [('TECH', 290)]
# TECH 100.0
#
# [('EDUCATION', 284)]
# EDUCATION 100.0
#
# [('PARENTS', 291)]
# PARENTS 100.0
#
# [('WORLDPOST', 284)]
# WORLDPOST 100.0
#
# [('WEIRD NEWS', 216), ('BLACK VOICES', 50)]
# WEIRD NEWS 81.203007518797
#
# [('STYLE & BEAUTY', 212), ('DIVORCE', 66)]
# STYLE & BEAUTY 76.2589928057554
#
# [('ARTS', 287), ('FIFTY', 2)]
# ARTS 99.30795847750865
#
# [('ARTS & CULTURE', 242), ('STYLE', 47)]
# ARTS & CULTURE 83.73702422145328
#
# [('TASTE', 280)]
# TASTE 100.0
#
# [('WORLD NEWS', 280)]
# WORLD NEWS 100.0
#
# [('SCIENCE', 181), ('RELIGION', 104)]
# ...
# [('QUEER VOICES', 258)]
# QUEER VOICES 100.0
#
# [('ARTS', 253)]
# ARTS 100.0
#
# [('ARTS & CULTURE', 139), ('PARENTS', 109)]
# ARTS & CULTURE 56.04838709677419
#
# [('FOOD & DRINK', 230), ('MONEY', 22)]
# FOOD & DRINK 91.26984126984127
#
# [('IMPACT', 223), ('WORLD NEWS', 28)]
# IMPACT 88.84462151394422
#
# [('SCIENCE', 154), ('LATINO VOICES', 104)]
# SCIENCE 59.689922480620154
#
# [('HEALTHY LIVING', 206), ('THE WORLDPOST', 31)]
# HEALTHY LIVING 86.91983122362869
#
# [('MEDIA', 247)]
# MEDIA 100.0
#
# [('STYLE & BEAUTY', 253)]
# STYLE & BEAUTY 100.0
#
# [('WEIRD NEWS', 249), ('POLITICS', 11)]
# WEIRD NEWS 95.76923076923077
#
# [('ENVIRONMENT', 231), ('CULTURE & ARTS', 14)]
# ENVIRONMENT 94.28571428571429
#
# [('ENTERTAINMENT', 229), ('CRIME', 15)]
# ENTERTAINMENT 93.85245901639344
#
# [('WORLDPOST', 247)]
# WORLDPOST 100.0
#
# [('WOMEN', 266)]
# WOMEN 100.0
#
# [('GREEN', 239)]
# GREEN 100.0
#
# [('COLLEGE', 134), ('EDUCATION', 121)]
# COLLEGE 52.549019607843135
#
# [('TECH', 170), ('RELIGION', 81)]
# TECH 67.72908366533865
#
# [('WEDDINGS', 238), ('FOOD & DRINK', 17)]
# WEDDINGS 93.33333333333333
#
# [('HOME & LIVING', 244), ('PARENTING', 4)]
# HOME & LIVING 98.38709677419355
#
# [('BUSINESS', 247)]
# BUSINESS 100.0
#
# [('WELLNESS', 252)]
# WELLNESS 100.0
#
# [('THE WORLDPOST', 230), ('GOOD NEWS', 10)]
# THE WORLDPOST 95.83333333333333
#
# [('STYLE', 130), ('ARTS & CULTURE', 114)]
# STYLE 53.278688524590166
#
# [('COMEDY', 261)]
# COMEDY 100.0
#
# [('BLACK VOICES', 263)]
# BLACK VOICES 100.0
#
# [('CRIME', 243)]
# CRIME 100.0
#
# [('FIFTY', 250)]
# FIFTY 100.0
#
# [('LATINO VOICES', 259)]
# LATINO VOICES 100.0
#
# [('MONEY', 227), ('ENVIRONMENT', 22)]
# MONEY 91.16465863453816
#
# [('RELIGION', 165), ('SCIENCE', 90)]
# RELIGION 64.70588235294117
#
# [('PARENTS', 140), ('COLLEGE', 112)]
# PARENTS 55.55555555555556
#
# [('GOOD NEWS', 244)]
# GOOD NEWS 100.0
#
# [('DIVORCE', 248), ('WEDDINGS', 7)]
# DIVORCE 97.25490196078431
#
# [('TASTE', 236)]
# TASTE 100.0
#
# [('SPORTS', 252)]
# SPORTS 100.0
#
# [('IMPACT', 253)]
# IMPACT 100.0
#
# [('WORLD NEWS', 223), ('ENTERTAINMENT', 24)]
# WORLD NEWS 90.2834008097166
#
# [('PARENTING', 248), ('WELLNESS', 2)]
# PARENTING 99.2
#
# [('MEDIA', 168), ('TECH', 79)]
# MEDIA 68.01619433198381
#
# [('CULTURE & ARTS', 241)]
# CULTURE & ARTS 100.0
#
# [('FOOD & DRINK', 253)]
# FOOD & DRINK 100.0
#
# [('EDUCATION', 257)]
# EDUCATION 100.0
#
# [('HOME & LIVING', 250)]
# HOME & LIVING 100.0
#
# [('POLITICS', 231), ('IMPACT', 24)]
# POLITICS 90.58823529411765
#
# [('WOMEN', 194), ('COMEDY', 70)]
# WOMEN 73.48484848484848
#
# [('PARENTS', 251)]
# PARENTS 100.0
#
# [('BLACK VOICES', 226), ('WOMEN', 40)]
# BLACK VOICES 84.9624060150376
#
# [('SCIENCE', 256)]
# SCIENCE 100.0
#
# [('STYLE', 242)]
# STYLE 100.0
#
# [('RELIGION', 254)]
# RELIGION 100.0
#
# [('LATINO VOICES', 137), ('EDUCATION', 122)]
# LATINO VOICES 52.8957528957529
#
# [('TRAVEL', 244)]
# TRAVEL 100.0
#
# [('MONEY', 251)]
# MONEY 100.0
#
# [('ARTS', 240), ('FIFTY', 11)]
# ARTS 95.61752988047809
#
# [('QUEER VOICES', 151), ('SPORTS', 103)]
# QUEER VOICES 59.44881889763779
#
# [('CRIME', 242)]
# CRIME 100.0
#
# [('ENVIRONMENT', 247)]
# ENVIRONMENT 100.0
#
# [('GREEN', 150), ('TASTE', 87)]
# GREEN 63.29113924050633
#
# [('WEIRD NEWS', 251), ('BLACK VOICES', 11)]
# WEIRD NEWS 95.80152671755725
#
# [('WEDDINGS', 255)]
# WEDDINGS 100.0
#
# [('THE WORLDPOST', 239)]
# THE WORLDPOST 100.0
#
# [('COMEDY', 169), ('QUEER VOICES', 91)]
# COMEDY 65.0
#
# [('GOOD NEWS', 242)]
# GOOD NEWS 100.0
#
# [('CULTURE & ARTS', 244)]
# CULTURE & ARTS 100.0
#
# [('DIVORCE', 252), ('STYLE & BEAUTY', 1)]
# DIVORCE 99.60474308300395
#
# [('ARTS & CULTURE', 247)]
# ARTS & CULTURE 100.0
#
# [('PARENTING', 248)]
# PARENTING 100.0
#
# [('WORLDPOST', 242), ('GOOD NEWS', 4)]
# WORLDPOST 98.3739837398374
#
# [('WORLD NEWS', 249)]
# WORLD NEWS 100.0
#
# [('TASTE', 177), ('HEALTHY LIVING', 58)]
# TASTE 75.31914893617021
#
# [('POLITICS', 258)]
# POLITICS 100.0
#
# [('TRAVEL', 161), ('MEDIA', 85)]
# TRAVEL 65.44715447154472
#
# [('TECH', 251)]
# TECH 100.0
#
# [('FIFTY', 239), ('WORLDPOST', 11)]
# FIFTY 95.6
#
# [('SPORTS', 145), ('BUSINESS', 103)]
# SPORTS 58.46774193548387
#
# [('BUSINESS', 150), ('TRAVEL', 95)]
# BUSINESS 61.224489795918366
#
# [('STYLE', 128), ('GREEN', 111)]
# STYLE 53.55648535564853
#
# [('HEALTHY LIVING', 236)]
# HEALTHY LIVING 100.0
#
# [('WELLNESS', 246), ('ARTS', 7)]
# WELLNESS 97.23320158102767
#
# [('ENTERTAINMENT', 247)]
# ENTERTAINMENT 100.0
#
# [('COLLEGE', 254)]
# COLLEGE 100.0
#
# [('STYLE & BEAUTY', 246), ('HOME & LIVING', 6)]
# STYLE & BEAUTY 97.61904761904762
#
# Num clust  83
# Counter({36: 265, 13: 264, 69: 264, 67: 263, 48: 262, 19: 262, 30: 262, 9: 261, 16: 261, 46: 260, 12: 260, 43: 259, 76: 259, 28: 258, 49: 258, 24: 257, 7: 257, 82: 256, 52: 256, 74: 256, 32: 255, 56: 254, 53: 254, 1: 253, 4: 253, 41: 253, 60: 252, 38: 250, 77: 250, 3: 250, 58: 248, 25: 248, 27: 248, 23: 248, 78: 248, 31: 248, 5: 247, 42: 246, 66: 246, 14: 246, 62: 246, 59: 246, 65: 246, 64: 246, 70: 246, 34: 245, 63: 245, 39: 245, 8: 245, 11: 244, 45: 244, 47: 244, 21: 244, 44: 243, 15: 243, 0: 243, 55: 242, 17: 242, 29: 242, 54: 242, 22: 241, 2: 241, 72: 240, 50: 240, 51: 240, 26: 239, 35: 239, 79: 239, 81: 239, 40: 239, 80: 237, 71: 237, 73: 236, 61: 235, 18: 235, 10: 234, 75: 234, 37: 232, 6: 231, 68: 229, 33: 229, 57: 228, 20: 226})
# [('ARTS & CULTURE', 198), ('PARENTS', 45)]
# ARTS & CULTURE 81.48148148148148
#
# [('WOMEN', 253)]
# WOMEN 100.0
#
# [('DIVORCE', 241)]
# DIVORCE 100.0
#
# [('WORLDPOST', 250)]
# WORLDPOST 100.0
#
# [('TECH', 188), ('RELIGION', 65)]
# TECH 74.30830039525692
#
# [('IMPACT', 209), ('WORLD NEWS', 38)]
# IMPACT 84.61538461538461
#
# [('MONEY', 143), ('ENVIRONMENT', 88)]
# MONEY 61.904761904761905
#
# [('GREEN', 257)]
# GREEN 100.0
#
# [('PARENTING', 245)]
# PARENTING 100.0
#
# [('SPORTS', 224), ('QUEER VOICES', 37)]
# SPORTS 85.82375478927203
#
# [('COLLEGE', 234)]
# COLLEGE 100.0
#
# [('ENTERTAINMENT', 244)]
# ENTERTAINMENT 100.0
#
# [('THE WORLDPOST', 260)]
# THE WORLDPOST 100.0
#
# [('BUSINESS', 250), ('SPORTS', 14)]
# BUSINESS 94.6969696969697
#
# [('WEIRD NEWS', 190), ('POLITICS', 56)]
# WEIRD NEWS 77.23577235772358
#
# [('SCIENCE', 189), ('LATINO VOICES', 54)]
# SCIENCE 77.77777777777777
#
# [('TRAVEL', 222), ('MEDIA', 39)]
# TRAVEL 85.05747126436782
#
# [('ARTS', 242)]
# ARTS 100.0
#
# [('FOOD & DRINK', 235)]
# FOOD & DRINK 100.0
#
# [('TASTE', 262)]
# TASTE 100.0
#
# [('CULTURE & ARTS', 225)]
# CULTURE & ARTS 100.0
#
# [('STYLE & BEAUTY', 244)]
# STYLE & BEAUTY 100.0
#
# [('CRIME', 241)]
# CRIME 100.0
#
# [('STYLE', 191), ('ARTS & CULTURE', 57)]
# STYLE 77.01612903225806
#
# [('QUEER VOICES', 204), ('COMEDY', 53)]
# QUEER VOICES 79.37743190661479
#
# [('BLACK VOICES', 184), ('WEIRD NEWS', 64)]
# BLACK VOICES 74.19354838709677
#
# [('LATINO VOICES', 204), ('EDUCATION', 35)]
# LATINO VOICES 85.35564853556485
#
# [('RELIGION', 183), ('SCIENCE', 65)]
# RELIGION 73.79032258064517
#
# [('MEDIA', 202), ('TECH', 56)]
# MEDIA 78.29457364341086
#
# [('WELLNESS', 242)]
# WELLNESS 100.0
#
# [('HEALTHY LIVING', 257), ('THE WORLDPOST', 5)]
# HEALTHY LIVING 98.09160305343511
#
# [('HOME & LIVING', 248)]
# HOME & LIVING 100.0
#
# [('GOOD NEWS', 255)]
# GOOD NEWS 100.0
#
# [('ENVIRONMENT', 183), ('CULTURE & ARTS', 46)]
# ENVIRONMENT 79.91266375545851
#
# [('POLITICS', 200), ('IMPACT', 45)]
# POLITICS 81.63265306122449
#
# [('PARENTS', 216), ('COLLEGE', 23)]
# PARENTS 90.3765690376569
#
# [('BUSINESS', 250), ('TRAVEL', 15)]
# BUSINESS 94.33962264150944
#
# [('MONEY', 232)]
# MONEY 100.0
#
# [('BLACK VOICES', 250)]
# BLACK VOICES 100.0
#
# [('FIFTY', 224), ('ARTS', 21)]
# FIFTY 91.42857142857143
#
# [('WEDDINGS', 239)]
# WEDDINGS 100.0
#
# [('STYLE', 253)]
# STYLE 100.0
#
# [('WORLD NEWS', 214), ('ENTERTAINMENT', 32)]
# WORLD NEWS 86.99186991869918
#
# [('QUEER VOICES', 259)]
# QUEER VOICES 100.0
#
# [('ENTERTAINMENT', 224), ('CRIME', 19)]
# ENTERTAINMENT 92.18106995884774
#
# [('POLITICS', 244)]
# POLITICS 100.0
#
# [('TASTE', 217), ('GREEN', 43)]
# TASTE 83.46153846153847
#
# [('PARENTING', 229), ('WELLNESS', 15)]
# PARENTING 93.85245901639344
#
# [('SPORTS', 262)]
# SPORTS 100.0
#
# [('THE WORLDPOST', 235), ('GOOD NEWS', 23)]
# THE WORLDPOST 91.08527131782945
#
# [('ARTS', 237), ('WELLNESS', 3)]
# ARTS 98.75
#
# [('WELLNESS', 240)]
# WELLNESS 100.0
#
# [('TECH', 256)]
# TECH 100.0
#
# [('GOOD NEWS', 222), ('WORLDPOST', 32)]
# GOOD NEWS 87.4015748031496
#
# [('DIVORCE', 200), ('STYLE & BEAUTY', 42)]
# DIVORCE 82.64462809917356
#
# [('LATINO VOICES', 242)]
# LATINO VOICES 100.0
#
# [('COMEDY', 191), ('WOMEN', 63)]
# COMEDY 75.19685039370079
#
# [('CULTURE & ARTS', 228)]
# CULTURE & ARTS 100.0
#
# [('WORLD NEWS', 248)]
# WORLD NEWS 100.0
#
# [('SCIENCE', 246)]
# SCIENCE 100.0
#
# [('RELIGION', 252)]
# RELIGION 100.0
#
# [('EDUCATION', 228), ('COLLEGE', 7)]
# EDUCATION 97.02127659574468
#
# [('WEIRD NEWS', 246)]
# WEIRD NEWS 100.0
#
# [('ARTS & CULTURE', 245)]
# ARTS & CULTURE 100.0
#
# [('HOME & LIVING', 220), ('PARENTING', 26)]
# HOME & LIVING 89.4308943089431
#
# [('FIFTY', 246)]
# FIFTY 100.0
#
# [('IMPACT', 246)]
# IMPACT 100.0
#
# [('TRAVEL', 263)]
# TRAVEL 100.0
#
# [('ENVIRONMENT', 229)]
# ENVIRONMENT 100.0
#
# [('HEALTHY LIVING', 243), ('TASTE', 21)]
# HEALTHY LIVING 92.04545454545455
#
# [('STYLE & BEAUTY', 214), ('HOME & LIVING', 32)]
# STYLE & BEAUTY 86.99186991869918
#
# [('FOOD & DRINK', 156), ('WEDDINGS', 81)]
# FOOD & DRINK 65.82278481012658
#
# [('CRIME', 240)]
# CRIME 100.0
#
# [('COLLEGE', 236)]
# COLLEGE 100.0
#
# [('GREEN', 200), ('STYLE', 56)]
# GREEN 78.125
#
# [('MONEY', 125), ('FOOD & DRINK', 109)]
# MONEY 53.41880341880342
#
# [('MEDIA', 259)]
# MEDIA 100.0
#
# [('WOMEN', 184), ('BLACK VOICES', 66)]
# WOMEN 73.6
#
# [('WORLDPOST', 218), ('FIFTY', 30)]
# WORLDPOST 87.90322580645162
#
# [('PARENTS', 239)]
# PARENTS 100.0
#
# [('EDUCATION', 237)]
# EDUCATION 100.0
#
# [('WEDDINGS', 180), ('DIVORCE', 59)]
# WEDDINGS 75.31380753138075
#
# [('COMEDY', 256)]
# COMEDY 100.0
#
# Num clust  84
# Counter({15: 258, 48: 257, 33: 256, 70: 256, 27: 256, 17: 255, 44: 255, 43: 255, 42: 254, 8: 254, 47: 254, 2: 253, 0: 252, 78: 252, 73: 252, 7: 252, 5: 251, 79: 250, 40: 250, 54: 250, 30: 250, 41: 250, 25: 249, 51: 249, 61: 249, 24: 249, 65: 247, 69: 247, 34: 247, 32: 247, 53: 247, 56: 247, 23: 246, 68: 246, 14: 246, 16: 245, 46: 245, 1: 245, 59: 245, 12: 245, 76: 244, 22: 244, 71: 244, 77: 243, 21: 243, 13: 243, 60: 243, 4: 243, 83: 243, 55: 243, 28: 242, 63: 242, 37: 242, 80: 241, 52: 241, 45: 241, 26: 241, 49: 240, 6: 240, 20: 240, 10: 240, 18: 240, 75: 240, 38: 239, 82: 239, 50: 239, 74: 239, 36: 238, 62: 238, 3: 238, 11: 236, 35: 236, 67: 235, 66: 234, 31: 234, 57: 234, 64: 233, 9: 232, 29: 231, 19: 231, 81: 230, 39: 230, 72: 229, 58: 229})
# [('POLITICS', 160), ('IMPACT', 92)]
# POLITICS 63.492063492063494
#
# [('WORLDPOST', 235), ('GOOD NEWS', 10)]
# WORLDPOST 95.91836734693878
#
# [('MEDIA', 136), ('TECH', 117)]
# MEDIA 53.75494071146245
#
# [('WEDDINGS', 177), ('DIVORCE', 61)]
# WEDDINGS 74.36974789915966
#
# [('STYLE', 243)]
# STYLE 100.0
#
# [('LATINO VOICES', 251)]
# LATINO VOICES 100.0
#
# [('BUSINESS', 133), ('SPORTS', 107)]
# BUSINESS 55.416666666666664
#
# [('PARENTING', 223), ('WELLNESS', 29)]
# PARENTING 88.4920634920635
#
# [('BLACK VOICES', 254)]
# BLACK VOICES 100.0
#
# [('ENVIRONMENT', 202), ('CULTURE & ARTS', 30)]
# ENVIRONMENT 87.06896551724138
#
# [('TASTE', 192), ('HEALTHY LIVING', 48)]
# TASTE 80.0
#
# [('ENTERTAINMENT', 236)]
# ENTERTAINMENT 100.0
#
# [('STYLE & BEAUTY', 214), ('HOME & LIVING', 31)]
# STYLE & BEAUTY 87.34693877551021
#
# [('COLLEGE', 243)]
# COLLEGE 100.0
#
# [('FIFTY', 246)]
# FIFTY 100.0
#
# [('RELIGION', 258)]
# RELIGION 100.0
#
# [('COMEDY', 245)]
# COMEDY 100.0
#
# [('WEIRD NEWS', 169), ('POLITICS', 86)]
# WEIRD NEWS 66.27450980392157
#
# [('THE WORLDPOST', 240)]
# THE WORLDPOST 100.0
#
# [('FOOD & DRINK', 121), ('MONEY', 110)]
# FOOD & DRINK 52.38095238095238
#
# [('ARTS & CULTURE', 240)]
# ARTS & CULTURE 100.0
#
# [('BUSINESS', 125), ('TRAVEL', 118)]
# BUSINESS 51.440329218106996
#
# [('GREEN', 244)]
# GREEN 100.0
#
# [('IMPACT', 158), ('WORLD NEWS', 88)]
# IMPACT 64.22764227642277
#
# [('HOME & LIVING', 222), ('PARENTING', 27)]
# HOME & LIVING 89.1566265060241
#
# [('WOMEN', 249)]
# WOMEN 100.0
#
# [('GOOD NEWS', 241)]
# GOOD NEWS 100.0
#
# [('SCIENCE', 141), ('RELIGION', 115)]
# SCIENCE 55.078125
#
# [('QUEER VOICES', 242)]
# QUEER VOICES 100.0
#
# [('CRIME', 231)]
# CRIME 100.0
#
# [('WELLNESS', 219), ('ARTS', 31)]
# WELLNESS 87.6
#
# [('FOOD & DRINK', 146), ('WEDDINGS', 88)]
# FOOD & DRINK 62.39316239316239
#
# [('WORLDPOST', 247)]
# WORLDPOST 100.0
#
# [('BLACK VOICES', 182), ('WEIRD NEWS', 74)]
# BLACK VOICES 71.09375
#
# [('EDUCATION', 247)]
# EDUCATION 100.0
#
# [('CULTURE & ARTS', 235)]
# CULTURE & ARTS 100.0
#
# [('WORLD NEWS', 169), ('ENTERTAINMENT', 69)]
# WORLD NEWS 71.00840336134453
#
# [('DIVORCE', 200), ('STYLE & BEAUTY', 42)]
# DIVORCE 82.64462809917356
#
# [('PARENTS', 128), ('ARTS & CULTURE', 111)]
# PARENTS 53.55648535564853
#
# [('ENVIRONMENT', 230)]
# ENVIRONMENT 100.0
#
# [('MEDIA', 250)]
# MEDIA 100.0
#
# [('PARENTING', 250)]
# PARENTING 100.0
#
# [('POLITICS', 254)]
# POLITICS 100.0
#
# [('LATINO VOICES', 151), ('SCIENCE', 104)]
# LATINO VOICES 59.21568627450981
#
# [('SCIENCE', 255)]
# SCIENCE 100.0
#
# [('TASTE', 241)]
# TASTE 100.0
#
# [('STYLE', 165), ('GREEN', 80)]
# STYLE 67.34693877551021
#
# [('TECH', 254)]
# TECH 100.0
#
# [('WEIRD NEWS', 257)]
# WEIRD NEWS 100.0
#
# [('SPORTS', 155), ('QUEER VOICES', 85)]
# SPORTS 64.58333333333333
#
# [('HEALTHY LIVING', 213), ('THE WORLDPOST', 26)]
# HEALTHY LIVING 89.1213389121339
#
# [('TRAVEL', 135), ('MEDIA', 114)]
# TRAVEL 54.21686746987952
#
# [('ARTS & CULTURE', 149), ('STYLE', 92)]
# ARTS & CULTURE 61.82572614107884
#
# [('ARTS', 220), ('FIFTY', 27)]
# ARTS 89.06882591093117
#
# [('EDUCATION', 152), ('LATINO VOICES', 98)]
# EDUCATION 60.8
#
# [('GOOD NEWS', 243)]
# GOOD NEWS 100.0
#
# [('HOME & LIVING', 247)]
# HOME & LIVING 100.0
#
# [('CULTURE & ARTS', 234)]
# CULTURE & ARTS 100.0
#
# [('MONEY', 161), ('ENVIRONMENT', 68)]
# MONEY 70.3056768558952
#
# [('FIFTY', 227), ('WORLDPOST', 18)]
# FIFTY 92.65306122448979
#
# [('PARENTS', 131), ('COLLEGE', 112)]
# PARENTS 53.90946502057613
#
# [('ARTS', 249)]
# ARTS 100.0
#
# [('SPORTS', 238)]
# SPORTS 100.0
#
# [('BUSINESS', 242)]
# BUSINESS 100.0
#
# [('FOOD & DRINK', 233)]
# FOOD & DRINK 100.0
#
# [('COMEDY', 184), ('WOMEN', 63)]
# COMEDY 74.49392712550608
#
# [('ENTERTAINMENT', 195), ('CRIME', 39)]
# ENTERTAINMENT 83.33333333333333
#
# [('WEDDINGS', 235)]
# WEDDINGS 100.0
#
# [('COLLEGE', 145), ('EDUCATION', 101)]
# COLLEGE 58.94308943089431
#
# [('TRAVEL', 247)]
# TRAVEL 100.0
#
# [('TECH', 129), ('RELIGION', 127)]
# TECH 50.390625
#
# [('STYLE & BEAUTY', 244)]
# STYLE & BEAUTY 100.0
#
# [('MONEY', 229)]
# MONEY 100.0
#
# [('WELLNESS', 252)]
# WELLNESS 100.0
#
# [('DIVORCE', 239)]
# DIVORCE 100.0
#
# [('THE WORLDPOST', 234), ('GOOD NEWS', 6)]
# THE WORLDPOST 97.5
#
# [('QUEER VOICES', 173), ('COMEDY', 71)]
# QUEER VOICES 70.90163934426229
#
# [('WORLD NEWS', 243)]
# WORLD NEWS 100.0
#
# [('WOMEN', 188), ('BLACK VOICES', 64)]
# WOMEN 74.60317460317461
#
# [('IMPACT', 250)]
# IMPACT 100.0
#
# [('PARENTS', 241)]
# PARENTS 100.0
#
# [('CRIME', 230)]
# CRIME 100.0
#
# [('HEALTHY LIVING', 239)]
# HEALTHY LIVING 100.0
#
# [('GREEN', 176), ('TASTE', 67)]
# GREEN 72.42798353909465
#
# Num clust  85
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-148-5db48f579c0a> in <module>()
#      20 for n_cluster in range(n_unique_cat,4*n_unique_cat):
#      21   print("Num clust ", n_cluster)
# ---> 22   kmeans = KMeans(n_clusters=n_cluster).fit(embeddings)
#      23   cluster_list = []
#      24   for i in range(n_cluster):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     935                     max_iter=self.max_iter, init=init, verbose=self.verbose,
#     936                     precompute_distances=precompute_distances, tol=tol,
# --> 937                     x_squared_norms=x_squared_norms, random_state=seed)
#     938                 # determine if these results are the best so far
#     939                 if best_inertia is None or inertia < best_inertia:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_kmeans.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     320     centers, labels, n_iter = k_means_elkan(X, checked_sample_weight,
#     321                                             n_clusters, centers, tol=tol,
# --> 322                                             max_iter=max_iter, verbose=verbose)
#     323     if sample_weight is None:
#     324         inertia = np.sum((X - centers[labels]) ** 2, dtype=np.float64)
#
# sklearn/cluster/_k_means_elkan.pyx in sklearn.cluster._k_means_elkan.k_means_elkan()
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create a Dataframe that has article to cluster mapping, which will be used by the downstream to find the trend

# %%
#Read the embeddings and do a Kmeans with k=41
n_cluster=41
embeddings = pd.read_csv("/content/drive/My Drive/Colab Notebooks/UBS_Pitch/articleToLatent.csv")
print(embeddings.shape)
print("Embedding loading done")
print("Num clust ", n_cluster)
#Kmeans
kmeans = KMeans(n_clusters=n_cluster).fit(embeddings)
ClusterIDs=kmeans.labels_
articles=pd.read_csv("/content/drive/My Drive/Colab Notebooks/UBS_Pitch/41category500ArticlesEachWithAuthorNames.csv")
articles['Cluster ID']=ClusterIDs.tolist()
articlesClusterID=articles[["category","headline","authors","date","Cluster ID"]]
articlesClusterID.to_csv("/content/drive/My Drive/Colab Notebooks/UBS_Pitch/articlesToClusterID.csv")
# Out:
# (20500, 257)
# Embedding loading done
# Num clust  41

# %% [markdown]
# ## Pass the articleToClusterID.csv to the downstream. Done
